# %% [markdown]
# # Normalizing institution `orgname` and `orgdiv1` at USP in `pt_BR`

# %% [markdown]
# For running this notebook you'll need some external packages,
# which can be installed with:
#
# ```shell
# pip install bs4 fuzzywuzzy lxml pandas Python-Levenshtein unidecode
# ```

# %%
import pandas as pd
pd.options.display.max_colwidth = 400 # Avoid "..." in large strings
pd.options.display.max_rows = 120     # Avoid "..." in the table representation of lengthy dataframes

# %% [markdown]
# ## The `institution_orgdiv1` in the CSV created from raw XML documents

# %% [markdown]
# This is the Clea's CSV generated from raw XML documents:

# %%
dataset = pd.read_csv("inner_join_2018-06-04.csv",
                      dtype=str,
                      keep_default_na=False) \
            .drop_duplicates()

# %% [markdown]
# The goal isn't to normalize everything, but a subset of the data.
# We're concerned with these columns/fields:

# %%
fields = [
    "addr_city",
    "addr_country",
    "addr_country_code",
    "addr_state",
    "institution_orgname",
    "institution_orgdiv1",
]
idataset = dataset[fields] # Input dataset

# %%
pd.DataFrame({
    "filled_in": (idataset.applymap(len) > 0).sum(),
    "distinct": idataset.apply(lambda col: col[col.apply(len) > 0].unique().size),
})
# Out:
#                      filled_in  distinct
# addr_city                79922      2728
# addr_country             85968       266
# addr_country_code        67724       124
# addr_state               68545       671
# institution_orgname      88527      9651
# institution_orgdiv1      56518      9903

# %% [markdown]
# Which are the most common rows?

# %%
idataset.groupby(fields) \
        .size() \
        .rename("count") \
        .sort_values(ascending=False) \
        .head(10) \
        .reset_index()
# Out:
#         addr_city addr_country addr_country_code addr_state  \
# 0
# 1       São Paulo       Brazil                BR         SP
# 2     Santa Maria       Brazil                BR         RS
# 3  Belo Horizonte       Brazil                BR         MG
# 4    Porto Alegre       Brazil                BR         RS
# 5     Santa Maria       Brazil                BR         RS
# 6                       Brasil                BR
# 7       São Paulo       Brazil                BR         SP
# 8       São Paulo       Brazil                BR         SP
# 9       São Paulo       Brazil                BR         SP
#
#                          institution_orgname          institution_orgdiv1  \
# 0
# 1                  Universidade de São Paulo        Faculdade de Medicina
# 2        Universidade Federal de Santa Maria
# 3       Universidade Federal de Minas Gerais
# 4  Universidade Federal do Rio Grande do Sul
# 5        Universidade Federal de Santa Maria    Centro de Ciências Rurais
# 6                                        USP         Escola de Enfermagem
# 7                  Universidade de São Paulo
# 8          Universidade Federal de São Paulo  Escola Paulista de Medicina
# 9          Universidade Federal de São Paulo
#
#    count
# 0    537
# 1    515
# 2    250
# 3    234
# 4    205
# 5    200
# 6    182
# 7    169
# 8    164
# 9    155

# %% [markdown]
# USP (University of São Paulo) has $3$ entries in this top $10$.
# There's no known number of typos, gross errors or inconsistencies for these fields,
# but we can assume that any information
# regarding normalizing this university name and its divisions' names
# should be helpful.
# On the other hand,
# seeing the raw "first division" names that follows,
# we know that:
#
# * There are more than a single writing for the same school/college/institute;
# * Sometimes their acronyms are used instead of their names;
# * Usually they're in Brazilian Portuguese but sometimes they're not;
# * Sometimes they're not school/college/institute names, but:
#   * Internal departments names;
#   * NAP (research group) names;
#   * Graduate program names.

# %%
idataset[idataset["institution_orgname"].isin(["Universidade de São Paulo", "USP"])] \
        ["institution_orgdiv1"] \
        .drop_duplicates()
# Out:
# 50                                                                             Faculdade de Odontologia
# 267                                                                             Instituto Oceanográfico
# 348                                                                           Instituto de Oceanografia
# 390
# 941                                                                                  Escola Politécnica
# 988                                                                  Escola de Engenharia de São Carlos
# 1134                                                     Escola Superior de Agricultura Luiz de Queiroz
# 1194                                                                           Departamento de Ecologia
# 1214                                                   Escola Superior de Agricultura “Luiz de Queiroz”
# 1283                                                                                              ESALQ
# 1441                                                  Faculdade de Filosofia, Letras e Ciências Humanas
# 1485                                                                              Faculdade de Medicina
# 2773                                                                 Instituto de Química de São Carlos
# 2895                                                                                               FMRP
# 2904                                                                               Instituto de Química
# 2982                                        Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto
# 2997                                                                                Instituto de Física
# 3531                                                Departamento de Agroindústria, Alimentos e Nutrição
# 4104                                                             Department and Institute of Psychiatry
# 4105                                                                             Hospital Universitário
# 4360                                                                         Faculdade de Saúde Pública
# 4410                                                                                  Museu de Zoologia
# 4416                                                                   Museu de Arqueologia e Etnologia
# 4417                                                                           Instituto de Biociências
# 4665                                          Grupo de Apoio è Pesquisa em Alimentos e Nutrição (NAPAN)
# 4719                                                                Faculdade de Ciências Farmacêuticas
# 4725                                                                                          Pediatria
# 4733                                                 Equipe de Epidemiologia Clínica e Apoio è Pesquisa
# 4758                                                                       Instituto do Coração (InCor)
# 4769                                                          Departamento de Obstetrícia e Ginecologia
# 4772                                                                  Departamento de Gastroenterologia
# 4774                                                                        Departamento de Ginecologia
# 4776                                                        Divisão de transplante de Órgãos Digestivos
# 4781                                                               Departamento de Otorrinolaringologia
# 4782                                                                        Departamento de Biomecânica
# 4819                                                            Faculdade de Medicina de Ribeirão Preto
# 4896                                       Departamento de Moléstias Infecciosas e Parasitárias (LIMHC)
# 5049                                                                              Hospital das Clínicas
# 5054                                                             Instituto de Ortopedia e Traumatologia
# 5063                                                                               Instituto da Criança
# 5155                                                 Instituto do Câncer do Estado de São Paulo - ICESP
# 5166                                                                          Departamento de Pediatria
# 5167                                                               Fonoaudiologia e Terapia Ocupacional
# 5170                                                        Centro de Pesquisa Clínica e Epidemiológica
# 5173                                                                     Departamento de Clínica Médica
# 5176                                                                              Serviço de Audiologia
# 5214     Instituto de Ortopedia e Traumatologia, Hospital das Clínicas (HCFMUSP), Faculdade de Medicina
# 5218                                                                             Grupo de Ortogeriatria
# 5222                                             Hospital das Clinicas (HCFMUSP), Faculdade de Medicina
# 5227                                                                      Faculdade de Medicina (FMUSP)
# 5230                                                                        Faculdade de Medicina FMUSP
# 5251                                               Hospital das Clinicas HCFMUSP, Faculdade de Medicina
# 5254                                                                     Instituto de Medicina Tropical
# 5260                                               Hospital das Clínicas HCFMUSP, Faculdade de Medicina
# 5279                              Cirurgia de Cabeca e Pescoco, Faculdade de Medicina de Ribeirao Preto
# 5281                                                            Faculdade de Medicina de Ribeirao Preto
# 5646                                                           Centro de Energia Nuclear na Agricultura
# 5960                                                                           Instituto de Geociências
# 5963                                                                    Instituto de Energia e Ambiente
# 5986                                                                           Institute of Geosciences
#                                                       ...
# 74430                                    Department of Gynecology and Obstetrics, Obstetrics Discipline
# 76208                                                                          Departamento de Genética
# 77349                                                        Departamento de Engenharia de Biossistemas
# 77367                                                                          Departamento de Cirurgia
# 78168                                                      Departamento de Imunologia Clínica e Alergia
# 78298                                                           Institute of Orthopedy and Traumatology
# 78700                                                                      Escola de Comunicações Artes
# 79881                                                   Laboratório de Cardiologia Genética e Molecular
# 80047                                                                                  Clinics Hospital
# 80063                                                                       Department of Ophthalmology
# 80069                                                                         Division of Ophthalmology
# 80197                                                             Faculdade de Medina de Ribeirão Preto
# 81013                                    Hospital das Clínicas, Faculdade de Medicina de Ribeirão Preto
# 81179                                                              Escola de Educação Física e Esportes
# 81633                                                                          Departamento de Anatomia
# 81635                                                        Instituto do Câncer do Estado de São Paulo
# 81642                                                                Disciplina de Emergências Clínicas
# 82045                                                   Instituto do Coração, Disciplina de Cardiologia
# 82108                                                                            Ciências e Humanidades
# 82233                                                                           Departamento de Esporte
# 82376                                                                    Interunidades em Biotecnologia
# 82744                                                               Ciências e Letras de Ribeirão Preto
# 84008                                                               Departamento de Química Fundamental
# 84306                                                           Graduate Program in Preventive Medicine
# 84310                                                            Study Group for the Prevention of AIDS
# 84312                                                                              Psychology Institute
# 84317                                                                   Study Group for AIDS prevention
# 84378                                                                           School of Public Health
# 84479                                       Center for Epidemiological Research in Nutrition and Health
# 85125                                                                                              POLI
# 85134                                                                                              FZEA
# 85560                                                           Instituto Oscar Freire - Medicina Legal
# 85799                                                    Escola Superior de Agricultura Luis de Queiroz
# 85842                                                           Departamento de Hidráulica e Saneamento
# 85851                                                                       Departamento de Estatística
# 86059                                                                       Departamento de Entomologia
# 86258                                                 Escola Superior de Agricultutra “Luiz de Queiroz”
# 86388                                                     Departamento de Genética e Biologia Evolutiva
# 86528                                                                     Departamento de Microbiologia
# 88212                                                  Escola Superior de Agricultura “Luiz de Queiroz"
# 88323                                                                      Departamento de reumatologia
# 89094                                              Departamento de Bioquímica e Tecnologia Farmacêutica
# 89872                                        Departamento de Enfermagem Materno Infantil e Psiquiátrica
# 90381                                             Instituto de Pesquisa do Discurso do Sujeito Coletivo
# 90784                                                                             Faculdade de Economia
# 90998                                                                Núcleo de Pesquisas Internacionais
# 91024                                                      Programa de Pós-graduação em História Social
# 92093                                                                      Faculdade de Medicina da USP
# 92120                    Hospital das Clínicas da FMUSP and Instituto de Medicina Tropical de São Paulo
# 92286                                               DEPARTAMENTO DE FILOSOFIA E TEORIA GERAL DO DIREITO
# 92427                                             Programa de Pós-Graduação em Nutrição Humana Aplicada
# 92727                                                                Faculdade de Medicina de São Paulo
# 93109                                                               Hospital of the Faculty of Medicine
# 93424                                                                               Divisão de Urologia
# 93613                                                      Escola Superior de Agronomia Luiz de Queiroz
# 93615                                                                                               IPE
# 93616                                                                                             FEARP
# 94580                                    Center for Interdisciplinary Research on Applied Neurosciences
# 94636                                                                       Museu de Arte Contemporânea
# 94658                                                     Departamento de Letras Clássicas e Vernáculas
# Name: institution_orgdiv1, Length: 412, dtype: object

# %% [markdown]
# ## Getting the name of institutes, colleges and schools at USP (University of São Paulo)

# %% [markdown]
# The Brazilian Portuguese names
# for the USP institutes/colleges/schools
# can be found
# [here](http://www5.usp.br/institucional/escolas-faculdades-e-institutos/),
# and the English names can be found
# [here](http://www5.usp.br/english/institutional/escolas-faculdades-e-institutos-2/?lang=en).

# %%
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup
from lxml import etree

# %% [markdown]
# We can download the Brazilian Portuguese HTML:

# %%
pt_br_usp_ordgiv1_url = "http://www5.usp.br/institucional/escolas-faculdades-e-institutos/"
raw_html = urlopen(pt_br_usp_ordgiv1_url).read()
bsoup = BeautifulSoup(raw_html, "lxml")

# %% [markdown]
# Scraping the links with CSS is quite straightforward:

# %%
usp_orgdiv1_bsoup_info = pd.DataFrame([(el.text, el.attrs["href"])
                                       for el in bsoup.select(".post_content li a")],
                                       columns=["name", "url"])
usp_orgdiv1_bsoup_info.head()
# Out:
#                                              name                         url
# 0  Escola de Artes, Ciências e Humanidades (EACH)  http://each.uspnet.usp.br/
# 1            Escola de Comunicações e Artes (ECA)      http://www.eca.usp.br/
# 2      Escola de Educação Física e Esporte (EEFE)     http://www.eefe.usp.br/
# 3                       Escola de Enfermagem (EE)       http://www.ee.usp.br/
# 4                       Escola Politécnica (Poli)     http://www.poli.usp.br/

# %% [markdown]
# The cities aren't in these links,
# but in the previous `<h2>` heading,
# so we need to get them as well,
# but bs4 loses the elements' order when using the
# `.post_content li a | .post_content h2` CSS selector,
# so we need to use something else.
#
# With `lxml` directly
# and a custom dictionary to match the campus city
# with the school/college/institute element index, we get:

# %%
tree = etree.fromstring(raw_html, parser=etree.HTMLParser())
prefix_cutter_regex = re.compile("(?:Campus de |Em )(.*)")
a_h2_els = tree.xpath("//*[contains(@class, 'post_content')]//li/a | "
                      "//*[contains(@class, 'post_content')]//h2")

class PrevDict(dict):
    def __missing__(self, key):
        return next(self[k] for k in sorted(self, reverse=True) if k < key)

usp_campi = PrevDict((idx, prefix_cutter_regex.match(el.findtext("*")).groups()[0])
                     for idx, el in enumerate(a_h2_els) if el.tag == "h2")
usp_campi
# Out:
# {0: 'São Paulo',
#  30: 'Bauru',
#  32: 'São Carlos',
#  38: 'Lorena',
#  40: 'Piracicaba',
#  43: 'Pirassununga',
#  45: 'Ribeirão Preto',
#  54: 'São Sebastião'}

# %%
usp_orgdiv1 = pd.DataFrame([(usp_campi[idx], el.text, el.attrib["href"])
                            for idx, el in enumerate(a_h2_els)
                            if el.tag == "a"],
                           columns=["city", "name", "url"])
usp_orgdiv1.tail()
# Out:
#               city  \
# 43  Ribeirão Preto
# 44  Ribeirão Preto
# 45  Ribeirão Preto
# 46  Ribeirão Preto
# 47   São Sebastião
#
#                                                                               name  \
# 43  Faculdade de Economia, Administração e Contabilidade de Ribeirão Preto (FEARP)
# 44            Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto (FFCLRP)
# 45                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 46                               Faculdade de Odontologia de Ribeirão Preto (FORP)
# 47                                            Centro de Biologia Marinha (CEBIMar)
#
#                           url
# 43   http://www.fearp.usp.br/
# 44  http://www.ffclrp.usp.br/
# 45    http://www.fmrp.usp.br/
# 46    http://www.forp.usp.br/
# 47      http://www.usp.br/cbm

# %% [markdown]
# Here in this notebook, these scraped names will be seen as
# valid, normalized and consistent names for `addr_city` and `institution_orgdiv1`.

# %%
ndataset = usp_orgdiv1 \
    .rename(columns={"name": "institution_orgdiv1",
                     "city": "addr_city"}) \
    .assign(
        addr_country="Brazil",
        addr_country_code="BR",
        addr_state="SP",
        institution_orgname="Universidade de São Paulo (USP)",
    ).reindex(fields, axis=1)
ndataset # Ground-truth normalized dataset
# Out:
#          addr_city addr_country addr_country_code addr_state  \
# 0        São Paulo       Brazil                BR         SP
# 1        São Paulo       Brazil                BR         SP
# 2        São Paulo       Brazil                BR         SP
# 3        São Paulo       Brazil                BR         SP
# 4        São Paulo       Brazil                BR         SP
# 5        São Paulo       Brazil                BR         SP
# 6        São Paulo       Brazil                BR         SP
# 7        São Paulo       Brazil                BR         SP
# 8        São Paulo       Brazil                BR         SP
# 9        São Paulo       Brazil                BR         SP
# 10       São Paulo       Brazil                BR         SP
# 11       São Paulo       Brazil                BR         SP
# 12       São Paulo       Brazil                BR         SP
# 13       São Paulo       Brazil                BR         SP
# 14       São Paulo       Brazil                BR         SP
# 15       São Paulo       Brazil                BR         SP
# 16       São Paulo       Brazil                BR         SP
# 17       São Paulo       Brazil                BR         SP
# 18       São Paulo       Brazil                BR         SP
# 19       São Paulo       Brazil                BR         SP
# 20       São Paulo       Brazil                BR         SP
# 21       São Paulo       Brazil                BR         SP
# 22       São Paulo       Brazil                BR         SP
# 23       São Paulo       Brazil                BR         SP
# 24       São Paulo       Brazil                BR         SP
# 25       São Paulo       Brazil                BR         SP
# 26       São Paulo       Brazil                BR         SP
# 27       São Paulo       Brazil                BR         SP
# 28       São Paulo       Brazil                BR         SP
# 29           Bauru       Brazil                BR         SP
# 30      São Carlos       Brazil                BR         SP
# 31      São Carlos       Brazil                BR         SP
# 32      São Carlos       Brazil                BR         SP
# 33      São Carlos       Brazil                BR         SP
# 34      São Carlos       Brazil                BR         SP
# 35          Lorena       Brazil                BR         SP
# 36      Piracicaba       Brazil                BR         SP
# 37      Piracicaba       Brazil                BR         SP
# 38    Pirassununga       Brazil                BR         SP
# 39  Ribeirão Preto       Brazil                BR         SP
# 40  Ribeirão Preto       Brazil                BR         SP
# 41  Ribeirão Preto       Brazil                BR         SP
# 42  Ribeirão Preto       Brazil                BR         SP
# 43  Ribeirão Preto       Brazil                BR         SP
# 44  Ribeirão Preto       Brazil                BR         SP
# 45  Ribeirão Preto       Brazil                BR         SP
# 46  Ribeirão Preto       Brazil                BR         SP
# 47   São Sebastião       Brazil                BR         SP
#
#                 institution_orgname  \
# 0   Universidade de São Paulo (USP)
# 1   Universidade de São Paulo (USP)
# 2   Universidade de São Paulo (USP)
# 3   Universidade de São Paulo (USP)
# 4   Universidade de São Paulo (USP)
# 5   Universidade de São Paulo (USP)
# 6   Universidade de São Paulo (USP)
# 7   Universidade de São Paulo (USP)
# 8   Universidade de São Paulo (USP)
# 9   Universidade de São Paulo (USP)
# 10  Universidade de São Paulo (USP)
# 11  Universidade de São Paulo (USP)
# 12  Universidade de São Paulo (USP)
# 13  Universidade de São Paulo (USP)
# 14  Universidade de São Paulo (USP)
# 15  Universidade de São Paulo (USP)
# 16  Universidade de São Paulo (USP)
# 17  Universidade de São Paulo (USP)
# 18  Universidade de São Paulo (USP)
# 19  Universidade de São Paulo (USP)
# 20  Universidade de São Paulo (USP)
# 21  Universidade de São Paulo (USP)
# 22  Universidade de São Paulo (USP)
# 23  Universidade de São Paulo (USP)
# 24  Universidade de São Paulo (USP)
# 25  Universidade de São Paulo (USP)
# 26  Universidade de São Paulo (USP)
# 27  Universidade de São Paulo (USP)
# 28  Universidade de São Paulo (USP)
# 29  Universidade de São Paulo (USP)
# 30  Universidade de São Paulo (USP)
# 31  Universidade de São Paulo (USP)
# 32  Universidade de São Paulo (USP)
# 33  Universidade de São Paulo (USP)
# 34  Universidade de São Paulo (USP)
# 35  Universidade de São Paulo (USP)
# 36  Universidade de São Paulo (USP)
# 37  Universidade de São Paulo (USP)
# 38  Universidade de São Paulo (USP)
# 39  Universidade de São Paulo (USP)
# 40  Universidade de São Paulo (USP)
# 41  Universidade de São Paulo (USP)
# 42  Universidade de São Paulo (USP)
# 43  Universidade de São Paulo (USP)
# 44  Universidade de São Paulo (USP)
# 45  Universidade de São Paulo (USP)
# 46  Universidade de São Paulo (USP)
# 47  Universidade de São Paulo (USP)
#
#                                                                institution_orgdiv1
# 0                                   Escola de Artes, Ciências e Humanidades (EACH)
# 1                                             Escola de Comunicações e Artes (ECA)
# 2                                       Escola de Educação Física e Esporte (EEFE)
# 3                                                        Escola de Enfermagem (EE)
# 4                                                        Escola Politécnica (Poli)
# 5                                       Faculdade de Arquitetura e Urbanismo (FAU)
# 6                                        Faculdade de Ciências Farmacêuticas (FCF)
# 7                                                        Faculdade de Direito (FD)
# 8                       Faculdade de Economia, Administração e Contabilidade (FEA)
# 9                                                       Faculdade de Educação (FE)
# 10                       Faculdade de Filosofia, Letras e Ciências Humanas (FFLCH)
# 11                                                      Faculdade de Medicina (FM)
# 12                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 13                                                   Faculdade de Odontologia (FO)
# 14                                                Faculdade de Saúde Pública (FSP)
# 15                Instituto de Astronomia, Geofísica e Ciências Atmosféricas (IAG)
# 16                                                   Instituto de Biociências (IB)
# 17                                          Instituto de Ciências Biomédicas (ICB)
# 18                                           Instituto de Energia e Ambiente (IEE)
# 19                                            Instituto de Estudos Avançados (IEA)
# 20                                          Instituto de Estudos Brasileiros (IEB)
# 21                                                        Instituto de Física (IF)
# 22                                                  Instituto de Geociências (IGc)
# 23                                     Instituto de Matemática e Estatística (IME)
# 24                               Instituto de Medicina Tropical de São Paulo (IMT)
# 25                                                    Instituto de Psicologia (IP)
# 26                                                       Instituto de Química (IQ)
# 27                                      Instituto de Relações Internacionais (IRI)
# 28                                                    Instituto Oceanográfico (IO)
# 29                                         Faculdade de Odontologia de Bauru (FOB)
# 30                                       Escola de Engenharia de São Carlos (EESC)
# 31                                      Instituto de Arquitetura e Urbanismo (IAU)
# 32                        Instituto de Ciências Matemáticas e de Computação (ICMC)
# 33                                        Instituto de Física de São Carlos (IFSC)
# 34                                       Instituto de Química de São Carlos (IQSC)
# 35                                            Escola de Engenharia de Lorena (EEL)
# 36                                 Centro de Energia Nuclear na Agricultura (CENA)
# 37                                Escola Superior de Agricultura “Luiz de Queiroz”
# 38                         Faculdade de Zootecnia e Engenharia de Alimentos (FZEA)
# 39                  Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 40                                   Escola de Enfermagem de Ribeirão Preto (EERP)
# 41                   Faculdade de Ciências Farmacêuticas de Ribeirão Preto (FCFRP)
# 42                                   Faculdade de Direito de Ribeirão Preto (FDRP)
# 43  Faculdade de Economia, Administração e Contabilidade de Ribeirão Preto (FEARP)
# 44            Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto (FFCLRP)
# 45                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 46                               Faculdade de Odontologia de Ribeirão Preto (FORP)
# 47                                            Centro de Biologia Marinha (CEBIMar)

# %% [markdown]
# Rows that have the same information from this normalized dataset,
# perhaps with some missing field,
# are consistent.

# %% [markdown]
# This table misses historical schools/colleges/institutes changes
# and perhaps some nuances,
# e.g. the music department at FFCLRP used to be the
# [CMU-RP department at ECA](https://web.archive.org/web/20070614064907/http://www.musica.pcarp.usp.br/)
# (i.e., it used to be a department of a school that happens to be in another city,
#  $315 km$ away from the remaining departments).

# %% [markdown]
# ## Fuzzy similarity (Levenshtein distance) per institution field with `fuzzywuzzy`

# %%
from fuzzywuzzy import process
import operator
from unidecode import unidecode

# %% [markdown]
# At first, let's perform a simple pre-normalization on the data
# so that we don't have to worry about
# the letter case and surrounding symbols.

# %%
def pre_normalize(name):
    return " ".join(re.sub("[^a-zA-Z ]", "", unidecode(name)).split()).lower()

# %%
npre = ndataset.applymap(pre_normalize)
ipre = idataset.applymap(pre_normalize)

# %%
norgnames = npre["institution_orgname"].unique()
norgnames
# Out:
# array(['universidade de sao paulo usp'], dtype=object)

# %%
iorgnames = ipre["institution_orgname"].unique()
iorgnames
# Out:
# array(['universidade federal do rio grande do sul ufrgs',
#        'instituto federal sulriograndense ifsul',
#        'universidade federal do rio de janeiro ufrj', ...,
#        'universidade de lille i',
#        'universidade federal de mato grosso de sul',
#        'centro latinoamericano em sexualidade e direitos humanos'],
#       dtype=object)

# %% [markdown]
# Using [`fuzzywuzzy`](https://github.com/seatgeek/fuzzywuzzy),
# we can find the university names that best match the full USP name:

# %%
sorted(
    process.extractWithoutOrder(
        query=norgnames[0],
        choices=iorgnames,
        score_cutoff=88,
    ),
    key=operator.itemgetter(1),
    reverse=True,
)
# Out:
# [('universidade de sao paulo usp', 100),
#  ('universidade de sao paulousp', 98),
#  ('universidade de sao paulo fmusp', 97),
#  ('universidade de sao paulo unesp', 97),
#  ('universidade de sao paulo', 95),
#  ('universidade sao paulo', 95),
#  ('universidade de sao usp', 95),
#  ('universidade de sao paulo sao paulo', 95),
#  ('universidade de sao paulo hcfmusp', 94),
#  ('universidade de sao paulo esalqusp', 92),
#  ('univesidade de sao paulo', 91),
#  ('universidade de sao paul', 91),
#  ('universidad de sao paulo', 91),
#  ('universidade de sao paulo ib', 91),
#  ('universi dade de sao paulo', 91),
#  ('universiade de sao paulo', 91),
#  ('universidade de s paulo', 90),
#  ('department of psychiatry and institute of psychiatry universidade de sao paulo usp',
#   90),
#  ('universidade de sao paulo brasil', 89),
#  ('universidade federal de sao paulo', 88),
#  ('universidade federal de sao paulo unifesp', 88),
#  ('universidade estadual de sao paulo', 88),
#  ('universidade cidade de sao paulo', 88),
#  ('universidade anhanguera de sao paulo', 88),
#  ('universidade catolica de sao paulo', 88),
#  ('universidade do estado de sao paulo', 88),
#  ('universidade metodista de sao paulo', 88),
#  ('universidade adventista de sao paulo', 88),
#  ('universidade estadual de sao paulo unesp', 88),
#  ('universidade paulista de sao paulo', 88),
#  ('universidade de sao paulo de ribeirao preto', 88),
#  ('universidade federal do estado de sao paulo', 88)]

# %% [markdown]
# Similarities in fuzzywuzzy range from $0$ (no common character)
# to $100$ (equalness), using whole numbers.
# In this example, similarities greater than $88$
# are valid names for "Universidade de São Paulo (USP)".
# However, this threshold is specific to this dataset,
# and it doesn't seem something easy to find.

# %% [markdown]
# However, that's still brittle: if we remove the acronym suffix,
# we get several false positives with similarity equal to $95$:

# %%
sorted(
    process.extractWithoutOrder(
        query="universidade de sao paulo",
        choices=iorgnames,
        score_cutoff=94,
    ),
    key=operator.itemgetter(1),
    reverse=True,
)
# Out:
# [('universidade de sao paulo', 100),
#  ('univesidade de sao paulo', 98),
#  ('universidade de sao paul', 98),
#  ('universidad de sao paulo', 98),
#  ('universi dade de sao paulo', 98),
#  ('universiade de sao paulo', 98),
#  ('universidade de s paulo', 96),
#  ('universidade federal de sao paulo', 95),
#  ('universidade sao paulo', 95),
#  ('universidade de sao paulo usp', 95),
#  ('universidade de sao paulo fmusp', 95),
#  ('universidade estadual de sao paulo', 95),
#  ('universidade de sao paulo hcfmusp', 95),
#  ('universidade cidade de sao paulo', 95),
#  ('universidade anhanguera de sao paulo', 95),
#  ('universidade catolica de sao paulo', 95),
#  ('universidade do estado de sao paulo', 95),
#  ('universidade de sao paulo brasil', 95),
#  ('universidade metodista de sao paulo', 95),
#  ('universidade de sao paulo esalqusp', 95),
#  ('universidade adventista de sao paulo', 95),
#  ('universidade de sao paulo sao paulo', 95),
#  ('universidade de sao paulo ib', 95),
#  ('universidade de sao paulo unesp', 95),
#  ('universidade paulista de sao paulo', 95),
#  ('universidade de sao paulousp', 94)]

# %% [markdown]
# Another approach would be a comparison with all alternative names,
# choosing the best one (i.e., reversing the input parameters),
# but there's no other alternative name yet,
# at least not for the university name.

# %% [markdown]
# Several university names have more information,
# like the `ib`, `hcfmusp` and `esalqusp` suffix,
# which might be useful for filling the `orgdiv1`.

# %% [markdown]
# Using $89$ as the threshold in the previous list
# based on the full university name with its acronym,
# and including the `"usp"` entry, we get these names:

# %%
usp_names = [name for name, score in process.extractWithoutOrder(
    query=norgnames[0],
    choices=iorgnames,
    score_cutoff=89,
)] + ["usp"]
usp_ipre_selector = ipre["institution_orgname"].isin(usp_names)
usp_names_raw = idataset[usp_ipre_selector]["institution_orgname"].unique().tolist()
usp_names_raw
# Out:
# ['Universidade de São Paulo',
#  'Universidade São Paulo',
#  'USP',
#  'Universidade de São Paulo (USP)',
#  'Universidade de São Paulo (FMUSP)',
#  'Universidade de São Paulo (HCFMUSP)',
#  'Universidade de São Paulo - USP',
#  'Universidade de Sao Paulo',
#  'Universidade de São Paulo, Brasil (1976)',
#  'Univesidade de Sao Paulo',
#  'Universidade de São Paulo – USP',
#  'Universidade de São – USP',
#  'Universidade de S. Paulo',
#  'Department of Psychiatry and Institute of Psychiatry, Universidade de São Paulo (USP)',
#  'Universidade de São Paulo (ESALQ-USP)',
#  'Universidade de São Paulo,',
#  'Universidade de São Paul',
#  'Universidad de São Paulo',
#  '>Universidade de São Paulo',
#  'U.S.P',
#  'Universidade de São Paulo São Paulo',
#  'Universidade de São Paulo IB',
#  'Universi dade de São Paulo',
#  'Universidade de São Paulo-USP',
#  'Universidade de São Paulo/USP',
#  'Universidade de São Paulo - FMUSP',
#  'Universidade de São Paulo, UNESP',
#  'Universiade de São Paulo',
#  '), Universidade de São Paulo',
#  'Universidade de São Paulo (USP',
#  'Universidade de São Paulo/']

# %% [markdown]
# There are $409$ distinct `orgdiv1` names
# in $6479$ entries for this university.

# %%
usp_ipre = ipre[usp_ipre_selector]
usp_ipre.shape
# Out:
# (6479, 6)

# %%
d1inames = usp_ipre["institution_orgdiv1"].drop_duplicates()
d1inames.shape
# Out:
# (409,)

# %% [markdown]
# Let's find the best match for all of them, using fuzzywuzzy:

# %%
norgdiv1s = npre["institution_orgdiv1"].unique()
od1_normalization_table = pd.DataFrame(
    d1inames.apply(
        lambda name:
            name
                and process.extractOne(query=name, choices=norgdiv1s, score_cutoff=80)
                or ("", 0)
    ).values.tolist(),
    index=d1inames.index,
    columns=["normalized", "similarity"],
).assign(orgdiv1=d1inames) \
 .reindex(["orgdiv1", "normalized", "similarity"], axis=1) \
 .sort_values(
     by=["similarity", "normalized", "orgdiv1"],
     ascending=[False, True, True],
 )
od1_normalization_table[lambda df: df["similarity"] >= 90]
# Out:
#                                                                                             orgdiv1  \
# 29887                                                   escola de artes ciencias e humanidades each
# 2445                                                        escola de engenharia de sao carlos eesc
# 1134                                                 escola superior de agricultura luiz de queiroz
# 4026                                                   faculdade de medicina de ribeirao preto fmrp
# 77496                                            faculdade de medicina veterinaria e zootecnia fmvz
# 87370                                                          instituto de ciencias biomedicas icb
# 86258                                               escola superior de agricultutra luiz de queiroz
# 85799                                                escola superior de agricultura luis de queiroz
# 6208                                      instituto de astronomia geofisica e ciencias atmosfericas
# 35600                         faculdade de economia administracao e contabilidade de ribeirao preto
# 9506                                            faculdade de economia administracao e contabilidade
# 33223                                                   instituto de medicina tropical de sao paulo
# 5646                                                       centro de energia nuclear na agricultura
# 6456                                                         escola de artes ciencias e humanidades
# 70236                                                          escola de artes ciencias humanidades
# 78700                                                                  escola de comunicacoes artes
# 20019                                                                escola de comunicacoes e artes
# 6249                                          escola de educacao fisica e esporte de ribeirao preto
# 6243                                                            escola de educacao fisica e esporte
# 49329                                                              escola de enfermagem de ribeirao
# 6497                                                         escola de enfermagem de ribeirao preto
# 6458                                                                           escola de enfermagem
# 36631                                                                escola de engenharia de lorena
# 988                                                              escola de engenharia de sao carlos
# 941                                                                              escola politecnica
# 41383                                                         escola de agricultura luiz de queiroz
# 40998                                          escola superior de agricultura luiz de queiroz esalq
# 45354                                       escola superior de agricultura luiz de queiroz esalqusp
# 67333                                           escola superior de agricultura luiz de queirozesalq
# 9516                                                           faculdade de arquitetura e urbanismo
# 19559                                         faculdade de ciencias farmaceuticas de ribeirao preto
# 4719                                                            faculdade de ciencias farmaceuticas
# 9501                                                                           faculdade de direito
# 37715                                                         faculdade de economia e administracao
# 10966                                                                         faculdade de educacao
# 2982                                     faculdade de filosofia ciencias e letras de ribeirao preto
# 57655                                                     faculdade de filosofia ciencias de letras
# 6321                                                       faculdade de filosofia ciencias e letras
# 1441                                               faculdade de filosofia letras e ciencias humanas
# 4819                                                        faculdade de medicina de ribeirao preto
# 30926                                                          faculdade medicina de ribeirao preto
# 54027                                                             faculdade medicina ribeirao preto
# 1485                                                                          faculdade de medicina
# 25577                                                 faculdade de medicina veterinaria e zootecnia
# 17107                                                             faculdade de odontologia de bauru
# 21783                                                    faculdade de odontologia de ribeirao preto
# 50                                                                         faculdade de odontologia
# 4360                                                                     faculdade de saude publica
# 27570                                              faculdade de zootecnia e engenharia de alimentos
# 4417                                                                       instituto de biociencias
# 10574                                                              instituto de ciencias biomedicas
# 24089                                             instituto de ciencias matematicas e de computacao
# 5963                                                                instituto de energia e ambiente
# 9517                                                                 instituto de estudos avancados
# 74371                                                              instituto de estudos brasileiros
# 9511                                                              instituto de fisica de sao carlos
# 2997                                                                            instituto de fisica
# 5960                                                                       instituto de geociencias
# 26609                                                         instituto de matematica e estatistica
# 9512                                                                        instituto de psicologia
# 2773                                                             instituto de quimica de sao carlos
# 2904                                                                           instituto de quimica
# 22737                                                          instituto de relacoes internacionais
# 267                                                                         instituto oceanografico
# 5227                                                                    faculdade de medicina fmusp
# 43846                                                  faculdade de medicina veterinaria e zootenia
# 36387                                     faculdade de filosofia ciencia e letras de ribeirao preto
# 74115                                                 faculdade de medicina veterinaria e zootencia
# 44522                                                         escola de artes ciencia e humanidades
# 81179                                                          escola de educacao fisica e esportes
# 47744                                                         escola de enfermagem de riberao preto
# 48988                                                        escola de enfermagem de ribeirao prelo
# 2441                                                                          escola politecnica ep
# 80197                                                         faculdade de medina de ribeirao preto
# 24967                                                              lnstituto de ciencias biomedicas
# 82108                                                                        ciencias e humanidades
# 48784                                                                  enfermagem de ribeirao preto
# 48673                                                                                    enfermagem
# 22714                                                                                          poli
# 54387                departamento de ciencia do solo escola superior de agricultura luiz de queiroz
# 40004  departamento de engenharia de biossistemas da escola superior de agricultura luiz de queiroz
# 90784                                                                         faculdade de economia
# 82744                                                           ciencias e letras de ribeirao preto
# 9529                                                                         faculdade de filosofia
# 74210                         departamento de clinica faculdade de medicina veterinaria e zootecnia
# 74147                       departamento de patologia faculdade de medicina veterinaria e zootecnia
# 73801                                                             faculdade de medicina veterinaria
# 35617                                                                       instituto de astronomia
# 5254                                                                 instituto de medicina tropical
#
#                                                                         normalized  \
# 29887                                  escola de artes ciencias e humanidades each
# 2445                                       escola de engenharia de sao carlos eesc
# 1134                                escola superior de agricultura luiz de queiroz
# 4026                                  faculdade de medicina de ribeirao preto fmrp
# 77496                           faculdade de medicina veterinaria e zootecnia fmvz
# 87370                                         instituto de ciencias biomedicas icb
# 86258                               escola superior de agricultura luiz de queiroz
# 85799                               escola superior de agricultura luiz de queiroz
# 6208                 instituto de astronomia geofisica e ciencias atmosfericas iag
# 35600  faculdade de economia administracao e contabilidade de ribeirao preto fearp
# 9506                       faculdade de economia administracao e contabilidade fea
# 33223                              instituto de medicina tropical de sao paulo imt
# 5646                                 centro de energia nuclear na agricultura cena
# 6456                                   escola de artes ciencias e humanidades each
# 70236                                  escola de artes ciencias e humanidades each
# 78700                                           escola de comunicacoes e artes eca
# 20019                                           escola de comunicacoes e artes eca
# 6249                  escola de educacao fisica e esporte de ribeirao preto eeferp
# 6243                                      escola de educacao fisica e esporte eefe
# 49329                                  escola de enfermagem de ribeirao preto eerp
# 6497                                   escola de enfermagem de ribeirao preto eerp
# 6458                                                       escola de enfermagem ee
# 36631                                           escola de engenharia de lorena eel
# 988                                        escola de engenharia de sao carlos eesc
# 941                                                        escola politecnica poli
# 41383                               escola superior de agricultura luiz de queiroz
# 40998                               escola superior de agricultura luiz de queiroz
# 45354                               escola superior de agricultura luiz de queiroz
# 67333                               escola superior de agricultura luiz de queiroz
# 9516                                      faculdade de arquitetura e urbanismo fau
# 19559                  faculdade de ciencias farmaceuticas de ribeirao preto fcfrp
# 4719                                       faculdade de ciencias farmaceuticas fcf
# 9501                                                       faculdade de direito fd
# 37715                      faculdade de economia administracao e contabilidade fea
# 10966                                                     faculdade de educacao fe
# 2982             faculdade de filosofia ciencias e letras de ribeirao preto ffclrp
# 57655                       faculdade de filosofia letras e ciencias humanas fflch
# 6321                        faculdade de filosofia letras e ciencias humanas fflch
# 1441                        faculdade de filosofia letras e ciencias humanas fflch
# 4819                                  faculdade de medicina de ribeirao preto fmrp
# 30926                                 faculdade de medicina de ribeirao preto fmrp
# 54027                                 faculdade de medicina de ribeirao preto fmrp
# 1485                                                      faculdade de medicina fm
# 25577                           faculdade de medicina veterinaria e zootecnia fmvz
# 17107                                        faculdade de odontologia de bauru fob
# 21783                              faculdade de odontologia de ribeirao preto forp
# 50                                                     faculdade de odontologia fo
# 4360                                                faculdade de saude publica fsp
# 27570                        faculdade de zootecnia e engenharia de alimentos fzea
# 4417                                                   instituto de biociencias ib
# 10574                                         instituto de ciencias biomedicas icb
# 24089                       instituto de ciencias matematicas e de computacao icmc
# 5963                                           instituto de energia e ambiente iee
# 9517                                            instituto de estudos avancados iea
# 74371                                         instituto de estudos brasileiros ieb
# 9511                                        instituto de fisica de sao carlos ifsc
# 2997                                                        instituto de fisica if
# 5960                                                  instituto de geociencias igc
# 26609                                    instituto de matematica e estatistica ime
# 9512                                                    instituto de psicologia ip
# 2773                                       instituto de quimica de sao carlos iqsc
# 2904                                                       instituto de quimica iq
# 22737                                     instituto de relacoes internacionais iri
# 267                                                     instituto oceanografico io
# 5227                                                      faculdade de medicina fm
# 43846                           faculdade de medicina veterinaria e zootecnia fmvz
# 36387            faculdade de filosofia ciencias e letras de ribeirao preto ffclrp
# 74115                           faculdade de medicina veterinaria e zootecnia fmvz
# 44522                                  escola de artes ciencias e humanidades each
# 81179                                     escola de educacao fisica e esporte eefe
# 47744                                  escola de enfermagem de ribeirao preto eerp
# 48988                                  escola de enfermagem de ribeirao preto eerp
# 2441                                                       escola politecnica poli
# 80197                                 faculdade de medicina de ribeirao preto fmrp
# 24967                                         instituto de ciencias biomedicas icb
# 82108                                  escola de artes ciencias e humanidades each
# 48784                                  escola de enfermagem de ribeirao preto eerp
# 48673                                                      escola de enfermagem ee
# 22714                                                      escola politecnica poli
# 54387                               escola superior de agricultura luiz de queiroz
# 40004                               escola superior de agricultura luiz de queiroz
# 90784                      faculdade de economia administracao e contabilidade fea
# 82744            faculdade de filosofia ciencias e letras de ribeirao preto ffclrp
# 9529                        faculdade de filosofia letras e ciencias humanas fflch
# 74210                           faculdade de medicina veterinaria e zootecnia fmvz
# 74147                           faculdade de medicina veterinaria e zootecnia fmvz
# 73801                           faculdade de medicina veterinaria e zootecnia fmvz
# 35617                instituto de astronomia geofisica e ciencias atmosfericas iag
# 5254                               instituto de medicina tropical de sao paulo imt
#
#        similarity
# 29887         100
# 2445          100
# 1134          100
# 4026          100
# 77496         100
# 87370         100
# 86258          99
# 85799          98
# 6208           97
# 35600          96
# 9506           96
# 33223          96
# 5646           95
# 6456           95
# 70236          95
# 78700          95
# 20019          95
# 6249           95
# 6243           95
# 49329          95
# 6497           95
# 6458           95
# 36631          95
# 988            95
# 941            95
# 41383          95
# 40998          95
# 45354          95
# 67333          95
# 9516           95
# 19559          95
# 4719           95
# 9501           95
# 37715          95
# 10966          95
# 2982           95
# 57655          95
# 6321           95
# 1441           95
# 4819           95
# 30926          95
# 54027          95
# 1485           95
# 25577          95
# 17107          95
# 21783          95
# 50             95
# 4360           95
# 27570          95
# 4417           95
# 10574          95
# 24089          95
# 5963           95
# 9517           95
# 74371          95
# 9511           95
# 2997           95
# 5960           95
# 26609          95
# 9512           95
# 2773           95
# 2904           95
# 22737          95
# 267            95
# 5227           94
# 43846          94
# 36387          93
# 74115          93
# 44522          92
# 81179          92
# 47744          92
# 48988          91
# 2441           91
# 80197          91
# 24967          91
# 82108          90
# 48784          90
# 48673          90
# 22714          90
# 54387          90
# 40004          90
# 90784          90
# 82744          90
# 9529           90
# 74210          90
# 74147          90
# 73801          90
# 35617          90
# 5254           90

# %%
od1_normalization_table[lambda df: df["similarity"] >= 90].shape
# Out:
# (89, 3)

# %% [markdown]
# These are the pre-normalized names.
# Let's see this fuzzywuzzy-based normalization
# applied to the actual `orgdiv1` values
# as they appear in the XML files:

# %%
npre_od1_pairs = ndataset[["institution_orgdiv1"]].assign(nn=npre["institution_orgdiv1"])
ipre_od1_pairs = idataset[usp_ipre_selector].assign(ni=ipre["institution_orgdiv1"])
fw_result = pd.merge(
    ipre_od1_pairs,
    pd.merge(od1_normalization_table, npre_od1_pairs, left_on="normalized", right_on="nn")
      .rename({"institution_orgdiv1": "institution_orgdiv1_normalized"}, axis=1),
    left_on="ni",
    right_on="orgdiv1",
).drop(columns=["ni", "orgdiv1", "normalized", "nn"]) \
 .rename({"institution_orgdiv1": "orgdiv1",
          "institution_orgdiv1_normalized": "normalized"},
         axis=1) \
 .groupby(["similarity", "normalized", "orgdiv1"]) \
 .size() \
 .rename("count") \
 .reset_index() \
 .reindex(["count", "orgdiv1", "normalized", "similarity"], axis=1) \
 .sort_values(
     by=["similarity", "normalized", "orgdiv1"],
     ascending=[False, True, True],
 )
fw_result[lambda df: df["similarity"] >= 90]
# Out:
#      count  \
# 320     27
# 321      1
# 322     58
# 323      3
# 324      1
# 325     44
# 326      2
# 327      1
# 328      2
# 329      1
# 330      3
# 331      5
# 332      3
# 319      1
# 318      1
# 316      1
# 317      6
# 313     33
# 314      3
# 315      6
# 243     23
# 244     50
# 245      1
# 246      1
# 247      1
# 248      1
# 249      1
# 250      1
# 251      3
# 252      2
# 253      1
# 254      2
# 255     66
# 256      1
# 257      2
# 258     68
# 259     17
# 260    423
# 261      1
# 262      3
# 263      1
# 264    310
# 265      1
# 266     12
# 267     40
# 268      5
# 269      1
# 270     25
# 271     43
# 272      6
# 273      1
# 274     18
# 275      3
# 276      2
# 277     34
# 278      2
# 279      1
# 280     11
# 281     25
# 282   1160
# 283    139
# 284      1
# 285      1
# 286      2
# 287      2
# 288    419
# 289     52
# 290    114
# 291      1
# 292     11
# 293      1
# 294    220
# 295     60
# 296     30
# 297     44
# 298     53
# 299      4
# 300      1
# 301      4
# 302      4
# 303      5
# 304      5
# 305     19
# 306     14
# 307     22
# 308      1
# 309     49
# 310     46
# 311     38
# 312      4
# 240      2
# 241      6
# 242      1
# 238      1
# 239      2
# 235      1
# 236      3
# 237      1
# 231      3
# 232      3
# 233      2
# 234      5
# 216      2
# 217      1
# 218      1
# 219      3
# 220      1
# 221      1
# 222      3
# 223      2
# 224      2
# 225      5
# 226      6
# 227      1
# 228      3
# 229      3
# 230      9
#
#                                                                                             orgdiv1  \
# 320                                                Escola Superior de Agricultura "Luiz de Queiroz"
# 321                                                Escola Superior de Agricultura 'Luiz de Queiroz'
# 322                                                  Escola Superior de Agricultura Luiz de Queiroz
# 323                                                  Escola Superior de Agricultura Luiz de Queiróz
# 324                                                Escola Superior de Agricultura “Luiz de Queiroz"
# 325                                                Escola Superior de Agricultura “Luiz de Queiroz”
# 326                                                Escola Superior de Agricultura “Luiz de Queiróz”
# 327                                                  Escola de Artes, Ciências e Humanidades (EACH)
# 328                                                       Escola de Engenharia de São Carlos (EESC)
# 329                                                       Escola de Engenharia de São Carlos – EESC
# 330                                             Faculdade de Medicina Veterinária e Zootecnia (FMVZ
# 331                                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 332                                                          Instituto de Ciências Biomédicas – ICB
# 319                                               Escola Superior de Agricultutra “Luiz de Queiroz”
# 318                                                  Escola Superior de Agricultura Luis de Queiroz
# 316                                       Instituto de Astronomia Geofísica e Ciências Atmosféricas
# 317                                      Instituto de Astronomia, Geofísica e Ciências Atmosféricas
# 313                                            Faculdade de Economia, Administração e Contabilidade
# 314                          Faculdade de Economia, Administração e Contabilidade de Ribeirão Preto
# 315                                                     Instituto de Medicina Tropical de São Paulo
# 243                                                        Centro de Energia Nuclear na Agricultura
# 244                                                                              Escola Politécnica
# 245                                    Escola Superior de Agricultura "Luiz de Queiroz" - Esalq/USP
# 246                                          Escola Superior de Agricultura "Luiz de Queiroz"/ESALQ
# 247                                          Escola Superior de Agricultura Luiz de Queiroz (ESALQ)
# 248                                          Escola Superior de Agricultura Luiz de Queiroz (Esalq)
# 249                                            Escola Superior de Agricultura Luiz de Queiroz/ESALQ
# 250                                        Escola Superior de Agricultura “Luiz de Queiroz” (ESALQ)
# 251                                        Escola Superior de Agricultura “Luiz de Queiroz” – ESALQ
# 252                                                         Escola de Agricultura “Luiz de Queiroz”
# 253                                                            Escola de Artes Ciencias Humanidades
# 254                                                          Escola de Artes Ciências e Humanidades
# 255                                                         Escola de Artes, Ciências e Humanidades
# 256                                                                    Escola de Comunicações Artes
# 257                                                                  Escola de Comunicações e Artes
# 258                                                             Escola de Educação Física e Esporte
# 259                                           Escola de Educação Física e Esporte de Ribeirão Preto
# 260                                                                            Escola de Enfermagem
# 261                                                                            Escola de enfermagem
# 262                                                          Escola de Enfermagem de Ribeirao Preto
# 263                                                                Escola de Enfermagem de Ribeirão
# 264                                                          Escola de Enfermagem de Ribeirão Preto
# 265                                                         Escola de Enfermagem de Ribeirão Preto-
# 266                                                                  Escola de Engenharia de Lorena
# 267                                                              Escola de Engenharia de São Carlos
# 268                                                            Faculdade de Arquitetura e Urbanismo
# 269                                                             Faculdade de Ciencias Farmacêuticas
# 270                                                             Faculdade de Ciências Farmacêuticas
# 271                                           Faculdade de Ciências Farmacêuticas de Ribeirão Preto
# 272                                                                            Faculdade de Direito
# 273                                                           Faculdade de Economia e Administração
# 274                                                                           Faculdade de Educação
# 275                                      Faculdade de Filosofia Ciências e Letras de Ribeirão Preto
# 276                                     Faculdade de Filosofia, Ciencias e Letras de Ribeirão Preto
# 277                                     Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto
# 278                                                Faculdade de Filosofia Letras e Ciências Humanas
# 279                                                      Faculdade de Filosofia, Ciências de Letras
# 280                                                       Faculdade de Filosofia, Ciências e Letras
# 281                                               Faculdade de Filosofia, Letras e Ciências Humanas
# 282                                                                           Faculdade de Medicina
# 283                                                   Faculdade de Medicina Veterinária e Zootecnia
# 284                                                  Faculdade de Medicina Veterinária e Zootecnia,
# 285                                                               Faculdade Medicina Ribeirão Preto
# 286                                                            Faculdade Medicina de Ribeirão Preto
# 287                                                         Faculdade de Medicina de Ribeirao Preto
# 288                                                         Faculdade de Medicina de Ribeirão Preto
# 289                                                                        Faculdade de Odontologia
# 290                                                               Faculdade de Odontologia de Bauru
# 291                                                               Faculdade de Odontologia de Baurú
# 292                                                      Faculdade de Odontologia de Ribeirão Preto
# 293                                                                      Faculdade de Saúde Publica
# 294                                                                      Faculdade de Saúde Pública
# 295                                                Faculdade de Zootecnia e Engenharia de Alimentos
# 296                                                                         Instituto Oceanográfico
# 297                                                                        Instituto de Biociências
# 298                                                                Instituto de Ciências Biomédicas
# 299                                                              Instituto de Ciências Biomédicas 5
# 300                                                              Instituto de Ciências Biomédicas-5
# 301                                               Instituto de Ciências Matemáticas e de Computação
# 302                                                                 Instituto de Energia e Ambiente
# 303                                                                  Instituto de Estudos Avançados
# 304                                                                Instituto de Estudos Brasileiros
# 305                                                                             Instituto de Física
# 306                                                               Instituto de Física de São Carlos
# 307                                                                        Instituto de Geociências
# 308                                                           Instituto de Matemática e Estatística
# 309                                                                         Instituto de Psicologia
# 310                                                                            Instituto de Química
# 311                                                              Instituto de Química de São Carlos
# 312                                                            Instituto de Relações Internacionais
# 240                                                                   Faculdade de Medicina (FMUSP)
# 241                                                                     Faculdade de Medicina FMUSP
# 242                                                    Faculdade de Medicina Veterinária e Zootenia
# 238                                      Faculdade de Filosofia, Ciência e Letras de Ribeirão Preto
# 239                                                   Faculdade de Medicina Veterinária e Zootencia
# 235                                                          Escola de Artes, Ciência e Humanidades
# 236                                                            Escola de Educação Física e Esportes
# 237                                                           Escola de Enfermagem de Riberão Preto
# 231                                                                         Escola Politécnica (EP)
# 232                                                          Escola de Enfermagem de Ribeirão Prelo
# 233                                                           Faculdade de Medina de Ribeirão Preto
# 234                                                                lnstituto de Ciências Biomédicas
# 216                                                                                            POLI
# 217                                                                                            Poli
# 218               Departamento de Ciência do Solo, Escola Superior de Agricultura “Luiz de Queiroz”
# 219  Departamento de Engenharia de Biossistemas da Escola Superior de Agricultura "Luiz de Queiroz"
# 220                                                                          Ciências e Humanidades
# 221                                                                                      Enfermagem
# 222                                                                    Enfermagem de Ribeirão Preto
# 223                                                                           Faculdade de Economia
# 224                                                             Ciências e Letras de Ribeirão Preto
# 225                                                                          Faculdade de Filosofia
# 226                          Departamento de Clínica, Faculdade de Medicina Veterinária e Zootecnia
# 227                        Departamento de Patologia, Faculdade de Medicina Veterinária e Zootecnia
# 228                                                               Faculdade de Medicina Veterinária
# 229                                                                         Instituto de Astronomia
# 230                                                                  Instituto de Medicina Tropical
#
#                                                                          normalized  \
# 320                                Escola Superior de Agricultura “Luiz de Queiroz”
# 321                                Escola Superior de Agricultura “Luiz de Queiroz”
# 322                                Escola Superior de Agricultura “Luiz de Queiroz”
# 323                                Escola Superior de Agricultura “Luiz de Queiroz”
# 324                                Escola Superior de Agricultura “Luiz de Queiroz”
# 325                                Escola Superior de Agricultura “Luiz de Queiroz”
# 326                                Escola Superior de Agricultura “Luiz de Queiroz”
# 327                                  Escola de Artes, Ciências e Humanidades (EACH)
# 328                                       Escola de Engenharia de São Carlos (EESC)
# 329                                       Escola de Engenharia de São Carlos (EESC)
# 330                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 331                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 332                                          Instituto de Ciências Biomédicas (ICB)
# 319                                Escola Superior de Agricultura “Luiz de Queiroz”
# 318                                Escola Superior de Agricultura “Luiz de Queiroz”
# 316                Instituto de Astronomia, Geofísica e Ciências Atmosféricas (IAG)
# 317                Instituto de Astronomia, Geofísica e Ciências Atmosféricas (IAG)
# 313                      Faculdade de Economia, Administração e Contabilidade (FEA)
# 314  Faculdade de Economia, Administração e Contabilidade de Ribeirão Preto (FEARP)
# 315                               Instituto de Medicina Tropical de São Paulo (IMT)
# 243                                 Centro de Energia Nuclear na Agricultura (CENA)
# 244                                                       Escola Politécnica (Poli)
# 245                                Escola Superior de Agricultura “Luiz de Queiroz”
# 246                                Escola Superior de Agricultura “Luiz de Queiroz”
# 247                                Escola Superior de Agricultura “Luiz de Queiroz”
# 248                                Escola Superior de Agricultura “Luiz de Queiroz”
# 249                                Escola Superior de Agricultura “Luiz de Queiroz”
# 250                                Escola Superior de Agricultura “Luiz de Queiroz”
# 251                                Escola Superior de Agricultura “Luiz de Queiroz”
# 252                                Escola Superior de Agricultura “Luiz de Queiroz”
# 253                                  Escola de Artes, Ciências e Humanidades (EACH)
# 254                                  Escola de Artes, Ciências e Humanidades (EACH)
# 255                                  Escola de Artes, Ciências e Humanidades (EACH)
# 256                                            Escola de Comunicações e Artes (ECA)
# 257                                            Escola de Comunicações e Artes (ECA)
# 258                                      Escola de Educação Física e Esporte (EEFE)
# 259                  Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 260                                                       Escola de Enfermagem (EE)
# 261                                                       Escola de Enfermagem (EE)
# 262                                   Escola de Enfermagem de Ribeirão Preto (EERP)
# 263                                   Escola de Enfermagem de Ribeirão Preto (EERP)
# 264                                   Escola de Enfermagem de Ribeirão Preto (EERP)
# 265                                   Escola de Enfermagem de Ribeirão Preto (EERP)
# 266                                            Escola de Engenharia de Lorena (EEL)
# 267                                       Escola de Engenharia de São Carlos (EESC)
# 268                                      Faculdade de Arquitetura e Urbanismo (FAU)
# 269                                       Faculdade de Ciências Farmacêuticas (FCF)
# 270                                       Faculdade de Ciências Farmacêuticas (FCF)
# 271                   Faculdade de Ciências Farmacêuticas de Ribeirão Preto (FCFRP)
# 272                                                       Faculdade de Direito (FD)
# 273                      Faculdade de Economia, Administração e Contabilidade (FEA)
# 274                                                      Faculdade de Educação (FE)
# 275            Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto (FFCLRP)
# 276            Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto (FFCLRP)
# 277            Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto (FFCLRP)
# 278                       Faculdade de Filosofia, Letras e Ciências Humanas (FFLCH)
# 279                       Faculdade de Filosofia, Letras e Ciências Humanas (FFLCH)
# 280                       Faculdade de Filosofia, Letras e Ciências Humanas (FFLCH)
# 281                       Faculdade de Filosofia, Letras e Ciências Humanas (FFLCH)
# 282                                                      Faculdade de Medicina (FM)
# 283                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 284                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 285                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 286                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 287                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 288                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 289                                                   Faculdade de Odontologia (FO)
# 290                                         Faculdade de Odontologia de Bauru (FOB)
# 291                                         Faculdade de Odontologia de Bauru (FOB)
# 292                               Faculdade de Odontologia de Ribeirão Preto (FORP)
# 293                                                Faculdade de Saúde Pública (FSP)
# 294                                                Faculdade de Saúde Pública (FSP)
# 295                         Faculdade de Zootecnia e Engenharia de Alimentos (FZEA)
# 296                                                    Instituto Oceanográfico (IO)
# 297                                                   Instituto de Biociências (IB)
# 298                                          Instituto de Ciências Biomédicas (ICB)
# 299                                          Instituto de Ciências Biomédicas (ICB)
# 300                                          Instituto de Ciências Biomédicas (ICB)
# 301                        Instituto de Ciências Matemáticas e de Computação (ICMC)
# 302                                           Instituto de Energia e Ambiente (IEE)
# 303                                            Instituto de Estudos Avançados (IEA)
# 304                                          Instituto de Estudos Brasileiros (IEB)
# 305                                                        Instituto de Física (IF)
# 306                                        Instituto de Física de São Carlos (IFSC)
# 307                                                  Instituto de Geociências (IGc)
# 308                                     Instituto de Matemática e Estatística (IME)
# 309                                                    Instituto de Psicologia (IP)
# 310                                                       Instituto de Química (IQ)
# 311                                       Instituto de Química de São Carlos (IQSC)
# 312                                      Instituto de Relações Internacionais (IRI)
# 240                                                      Faculdade de Medicina (FM)
# 241                                                      Faculdade de Medicina (FM)
# 242                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 238            Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto (FFCLRP)
# 239                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 235                                  Escola de Artes, Ciências e Humanidades (EACH)
# 236                                      Escola de Educação Física e Esporte (EEFE)
# 237                                   Escola de Enfermagem de Ribeirão Preto (EERP)
# 231                                                       Escola Politécnica (Poli)
# 232                                   Escola de Enfermagem de Ribeirão Preto (EERP)
# 233                                  Faculdade de Medicina de Ribeirão Preto (FMRP)
# 234                                          Instituto de Ciências Biomédicas (ICB)
# 216                                                       Escola Politécnica (Poli)
# 217                                                       Escola Politécnica (Poli)
# 218                                Escola Superior de Agricultura “Luiz de Queiroz”
# 219                                Escola Superior de Agricultura “Luiz de Queiroz”
# 220                                  Escola de Artes, Ciências e Humanidades (EACH)
# 221                                                       Escola de Enfermagem (EE)
# 222                                   Escola de Enfermagem de Ribeirão Preto (EERP)
# 223                      Faculdade de Economia, Administração e Contabilidade (FEA)
# 224            Faculdade de Filosofia, Ciências e Letras de Ribeirão Preto (FFCLRP)
# 225                       Faculdade de Filosofia, Letras e Ciências Humanas (FFLCH)
# 226                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 227                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 228                            Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 229                Instituto de Astronomia, Geofísica e Ciências Atmosféricas (IAG)
# 230                               Instituto de Medicina Tropical de São Paulo (IMT)
#
#      similarity
# 320         100
# 321         100
# 322         100
# 323         100
# 324         100
# 325         100
# 326         100
# 327         100
# 328         100
# 329         100
# 330         100
# 331         100
# 332         100
# 319          99
# 318          98
# 316          97
# 317          97
# 313          96
# 314          96
# 315          96
# 243          95
# 244          95
# 245          95
# 246          95
# 247          95
# 248          95
# 249          95
# 250          95
# 251          95
# 252          95
# 253          95
# 254          95
# 255          95
# 256          95
# 257          95
# 258          95
# 259          95
# 260          95
# 261          95
# 262          95
# 263          95
# 264          95
# 265          95
# 266          95
# 267          95
# 268          95
# 269          95
# 270          95
# 271          95
# 272          95
# 273          95
# 274          95
# 275          95
# 276          95
# 277          95
# 278          95
# 279          95
# 280          95
# 281          95
# 282          95
# 283          95
# 284          95
# 285          95
# 286          95
# 287          95
# 288          95
# 289          95
# 290          95
# 291          95
# 292          95
# 293          95
# 294          95
# 295          95
# 296          95
# 297          95
# 298          95
# 299          95
# 300          95
# 301          95
# 302          95
# 303          95
# 304          95
# 305          95
# 306          95
# 307          95
# 308          95
# 309          95
# 310          95
# 311          95
# 312          95
# 240          94
# 241          94
# 242          94
# 238          93
# 239          93
# 235          92
# 236          92
# 237          92
# 231          91
# 232          91
# 233          91
# 234          91
# 216          90
# 217          90
# 218          90
# 219          90
# 220          90
# 221          90
# 222          90
# 223          90
# 224          90
# 225          90
# 226          90
# 227          90
# 228          90
# 229          90
# 230          90

# %%
# Number of normalizations performed
fw_result[lambda df: df["similarity"] >= 90]["count"].sum()
# Out:
# 4010

# %% [markdown]
# Only $89$ distinct pre-normalized values out of $409$
# had a similarity of at least $90$,
# but these are $4010$ entries in this dataset,
# out of $6479$, that's more than $60\%$ of the data.

# %% [markdown]
# There are a lot of entries without the acronym,
# but that doesn't seem to be an issue:
# the default fuzzywuzzy comparison scorer is breaking the input as words
# (else these inputs with several extra/distinct words wouldn't match).

# %% [markdown]
# Let's see the remaining normalization entries
# that appeared at least $4$ times.

# %%
fw_result[lambda df: (df["similarity"] < 90) & (df["count"] > 3)]
# Out:
#      count  \
# 214      5
# 208      4
# 12       8
# 14       5
# 19       4
# 22       6
# 23       7
# 24       4
# 25       6
# 28       4
# 30       4
# 31       9
# 32       5
# 35       8
# 39       4
# 45       4
# 46       4
# 50      29
# 59      14
# 61       4
# 67       4
# 71       5
# 72       6
# 75      27
# 79       4
# 88      13
# 89      10
# 90       4
# 92      11
# 93      14
# 98       5
# 99      16
# 102     54
# 103     15
# 104      7
# 105      5
# 106      6
# 108      6
# 111      6
# 113      4
# 114      6
# 135      4
# 136      4
# 146      4
# 147      5
# 148      5
# 150      5
# 151      8
# 155      4
# 157      5
# 175      8
# 186      4
# 196      6
# 197     15
# 198      4
# 200      4
# 201      7
#
#                                                                                             orgdiv1  \
# 214                                  Hospital das Clínicas, Faculdade de Medicina de Ribeirão Preto
# 208                                                              Faculdade de Medicina de São Paulo
# 12                                                                         Departamento de Cirurgia
# 14                                                                         Departamento de Economia
# 19                                                                         Departamento de Genética
# 22                                                                       Departamento de Imunologia
# 23                                                                       Departamento de Neurologia
# 24                                                                     Departamento de Oftalmologia
# 25                                                                        Departamento de Patologia
# 28                                                                      Departamento de Psiquiatria
# 30                                                                       Departamento de Radiologia
# 31                                                                       Departamento de Sociologia
# 32                             Departamento de medicina veterinária preventiva e saúde animal (VPS)
# 35                                                                      Escola Paulista de Medicina
# 39                                                                            Faculdade de Farmácia
# 45   Instituto de Ortopedia e Traumatologia, Hospital das Clínicas (HCFMUSP), Faculdade de Medicina
# 46                                                                         Instituto de Psiquiatria
# 50                                                                                Museu de Zoologia
# 59                                   Departamento de Medicina Veterinária Preventiva e Saúde Animal
# 61                                  Departamento de Microbiologia, Instituto de Ciências Biomédicas
# 67                                  Divisão de Transplante de Fígado e Órgãos do Aparelho Digestivo
# 71                                           Hospital das Clinicas (HCFMUSP), Faculdade de Medicina
# 72                                             Hospital das Clinicas HCFMUSP, Faculdade de Medicina
# 75                                              Hospital de Reabilitação de Anomalias Craniofaciais
# 79                                            Laboratório de Nutrição de Plantas Prof. E. Malavolta
# 88                                                                  Dental School of Ribeirão Preto
# 89                                                            Faculty of Medicine of Ribeirao Preto
# 90                                                            Faculty of Medicine of Ribeirão Preto
# 92                                                                 Medical School of Ribeirão Preto
# 93                                                                 Nursing School of Ribeirão Preto
# 98                                                                     Ribeirão Preto Dental School
# 99                                                                    Ribeirão Preto Medical School
# 102                                                           School of Dentistry of Ribeirão Preto
# 103                                                            School of Medicine of Ribeirao Preto
# 104                                                            School of Medicine of Ribeirão Preto
# 105                                                                School of Nursing Ribeirão Preto
# 106                                                             School of Nursing of Ribeirão Preto
# 108                                                     Centro de Pesquisa Clínica e Epidemiológica
# 111                                                             Departamento de Cirurgia e Anatomia
# 113                                                Departamento de Enfermagem Geral e Especializada
# 114                                                    Departamento de Enfermagem em Saúde Coletiva
# 135                                                Department of Pathology of Faculdade de Medicina
# 136                                                     Divisão de transplante de Órgãos Digestivos
# 146                                             Hospital das Clínicas (HC) Faculdade de Medicina da
# 147                                                  Hospital das Clínicas da Faculdade de Medicina
# 148                                                         Hospital das Clínicas de Ribeirão Preto
# 150                                                    Hospital das Clínicas, Faculdade de Medicina
# 151                                                          Instituto de Ortopedia e Traumatologia
# 155                                              Instituto do Câncer do Estado de São Paulo - ICESP
# 157                                                        Laboratório de Hepatites Virais - LIM 47
# 175                                                                  Departamento de Clínica Médica
# 186                                                                Fundação de Otorrinolaringologia
# 196                                                                             Faculty of Medicina
# 197                                                                             Bauru Dental School
# 198                                                                          Dental School of Bauru
# 200                                                                            Instituto do Coração
# 201                                                                    Instituto do Coração (InCor)
#
#                                                            normalized  \
# 214                    Faculdade de Medicina de Ribeirão Preto (FMRP)
# 208                                        Faculdade de Medicina (FM)
# 12                     Escola de Artes, Ciências e Humanidades (EACH)
# 14                     Escola de Artes, Ciências e Humanidades (EACH)
# 19                     Escola de Artes, Ciências e Humanidades (EACH)
# 22                     Escola de Artes, Ciências e Humanidades (EACH)
# 23                     Escola de Artes, Ciências e Humanidades (EACH)
# 24                     Escola de Artes, Ciências e Humanidades (EACH)
# 25                     Escola de Artes, Ciências e Humanidades (EACH)
# 28                     Escola de Artes, Ciências e Humanidades (EACH)
# 30                     Escola de Artes, Ciências e Humanidades (EACH)
# 31                     Escola de Artes, Ciências e Humanidades (EACH)
# 32                     Escola de Artes, Ciências e Humanidades (EACH)
# 35                     Escola de Artes, Ciências e Humanidades (EACH)
# 39                     Escola de Artes, Ciências e Humanidades (EACH)
# 45                     Escola de Artes, Ciências e Humanidades (EACH)
# 46                     Escola de Artes, Ciências e Humanidades (EACH)
# 50                     Escola de Artes, Ciências e Humanidades (EACH)
# 59                               Escola de Comunicações e Artes (ECA)
# 61                               Escola de Comunicações e Artes (ECA)
# 67                               Escola de Comunicações e Artes (ECA)
# 71                               Escola de Comunicações e Artes (ECA)
# 72                               Escola de Comunicações e Artes (ECA)
# 75                               Escola de Comunicações e Artes (ECA)
# 79                               Escola de Comunicações e Artes (ECA)
# 88     Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 89     Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 90     Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 92     Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 93     Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 98     Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 99     Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 102    Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 103    Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 104    Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 105    Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 106    Escola de Educação Física e Esporte de Ribeirão Preto (EEFERP)
# 108                                         Escola de Enfermagem (EE)
# 111                                         Escola de Enfermagem (EE)
# 113                                         Escola de Enfermagem (EE)
# 114                                         Escola de Enfermagem (EE)
# 135                                         Escola de Enfermagem (EE)
# 136                                         Escola de Enfermagem (EE)
# 146                                         Escola de Enfermagem (EE)
# 147                                         Escola de Enfermagem (EE)
# 148                                         Escola de Enfermagem (EE)
# 150                                         Escola de Enfermagem (EE)
# 151                                         Escola de Enfermagem (EE)
# 155                                         Escola de Enfermagem (EE)
# 157                                         Escola de Enfermagem (EE)
# 175        Faculdade de Economia, Administração e Contabilidade (FEA)
# 186        Faculdade de Economia, Administração e Contabilidade (FEA)
# 196              Faculdade de Medicina Veterinária e Zootecnia (FMVZ)
# 197                           Faculdade de Odontologia de Bauru (FOB)
# 198                           Faculdade de Odontologia de Bauru (FOB)
# 200  Instituto de Astronomia, Geofísica e Ciências Atmosféricas (IAG)
# 201  Instituto de Astronomia, Geofísica e Ciências Atmosféricas (IAG)
#
#      similarity
# 214          89
# 208          88
# 12           86
# 14           86
# 19           86
# 22           86
# 23           86
# 24           86
# 25           86
# 28           86
# 30           86
# 31           86
# 32           86
# 35           86
# 39           86
# 45           86
# 46           86
# 50           86
# 59           86
# 61           86
# 67           86
# 71           86
# 72           86
# 75           86
# 79           86
# 88           86
# 89           86
# 90           86
# 92           86
# 93           86
# 98           86
# 99           86
# 102          86
# 103          86
# 104          86
# 105          86
# 106          86
# 108          86
# 111          86
# 113          86
# 114          86
# 135          86
# 136          86
# 146          86
# 147          86
# 148          86
# 150          86
# 151          86
# 155          86
# 157          86
# 175          86
# 186          86
# 196          86
# 197          86
# 198          86
# 200          86
# 201          86

# %% [markdown]
# When the similarity gets below $90$, it fails.
# As it seems, $86$ is a rather bad result,
# these happened because a single word had a full match,
# like *Instituto* in the latest entries,
# the *de* preposition in most entries,
# cities like *Bauru* and *Ribeirão Preto*, etc..
# Therefore, our threshould value should always be greater than $86$.
