# %% [markdown]
# # Looking for articles from public state universities in SP

# %% [markdown]
# There are $3$ public universities
# that are managed by the São Paulo state government:
#
# * USP, *Universidade de São Paulo*
# * UNICAMP, *Universidade Estadual de Campinas*
# * UNESP, *Universidade Estadual Paulista*
#
# The goal here is to find all research articles
# in the `scl` (SciELO Brazil) collection
# from any of these universities.

# %%
import re

# %%
import regex
import pandas as pd

# %% [markdown]
# ## Loading the data

# %% [markdown]
# The information about the university
# should be in the `documents_authors.csv` reports,
# but if there's no link between the authors and the given affiliations,
# it should still be in the `documents_affiliations.csv` file.
# Let's open these
# using the field name normalization step
# that can be found in <https://github.com/scieloorg/scielo20gt6/>:

# %%
def normalize_column_title(name):
    name_unbracketed = re.sub(r".*\((.*)\)", r"\1",
                              name.replace("(in months)", "in_months"))
    words = re.sub("[^a-z0-9+_ ]", "", name_unbracketed.lower()).split()
    ignored_words = ("at", "the", "of", "and", "google", "scholar", "+")
    replacements = {
        "document": "doc",
        "documents": "docs",
        "frequency": "freq",
        "language": "lang",
    }
    return "_".join(replacements.get(word, word)
                    for word in words if word not in ignored_words) \
              .replace("title_is", "is")

# %%
doc_affs = pd.read_csv("2018-11-10_scl/documents_affiliations.csv") \
             .rename(columns=normalize_column_title)

# %%
doc_authors = pd.read_csv("2018-11-10_scl/documents_authors.csv") \
                .rename(columns=normalize_column_title)

# %%
doc_affs.columns
# Out:
# Index(['extraction_date', 'study_unit', 'collection', 'issn_scielo', 'issns',
#        'title_scielo', 'title_thematic_areas', 'is_agricultural_sciences',
#        'is_applied_social_sciences', 'is_biological_sciences',
#        'is_engineering', 'is_exact_earth_sciences', 'is_health_sciences',
#        'is_human_sciences', 'is_linguistics_letters_arts',
#        'is_multidisciplinary', 'title_current_status', 'pid_scielo',
#        'doc_publishing_year', 'doc_type', 'doc_is_citable',
#        'doc_affiliation_instituition', 'doc_affiliation_country',
#        'doc_affiliation_country_iso_3166', 'doc_affiliation_state',
#        'doc_affiliation_city'],
#       dtype='object')

# %%
doc_authors.columns
# Out:
# Index(['extraction_date', 'study_unit', 'collection', 'issn_scielo', 'issns',
#        'title_scielo', 'title_thematic_areas', 'is_agricultural_sciences',
#        'is_applied_social_sciences', 'is_biological_sciences',
#        'is_engineering', 'is_exact_earth_sciences', 'is_health_sciences',
#        'is_human_sciences', 'is_linguistics_letters_arts',
#        'is_multidisciplinary', 'title_current_status', 'pid_scielo',
#        'doc_publishing_year', 'doc_type', 'doc_is_citable', 'doc_author',
#        'doc_author_institution', 'doc_author_affiliation_country',
#        'doc_author_affiliation_state', 'doc_author_affiliation_city'],
#       dtype='object')

# %%
doc_affs.tail(2).T
# Out:
#                                                                    817809  \
# extraction_date                                                2018-11-10
# study_unit                                                       document
# collection                                                            scl
# issn_scielo                                                     2446-4740
# issns                                                 2446-4732;2446-4740
# title_scielo                           Research on Biomedical Engineering
# title_thematic_areas                                          Engineering
# is_agricultural_sciences                                                0
# is_applied_social_sciences                                              0
# is_biological_sciences                                                  0
# is_engineering                                                          1
# is_exact_earth_sciences                                                 0
# is_health_sciences                                                      0
# is_human_sciences                                                       0
# is_linguistics_letters_arts                                             0
# is_multidisciplinary                                                    0
# title_current_status                                              current
# pid_scielo                                        S2446-47402018000300211
# doc_publishing_year                                                  2018
# doc_type                                                 research-article
# doc_is_citable                                                          1
# doc_affiliation_instituition      Institute Brasil of Health Technologies
# doc_affiliation_country                                            Brazil
# doc_affiliation_country_iso_3166                                       BR
# doc_affiliation_state                                                  RJ
# doc_affiliation_city                                       Rio de Janeiro
#
#                                                                   817810
# extraction_date                                               2018-11-10
# study_unit                                                      document
# collection                                                           scl
# issn_scielo                                                    2446-4740
# issns                                                2446-4732;2446-4740
# title_scielo                          Research on Biomedical Engineering
# title_thematic_areas                                         Engineering
# is_agricultural_sciences                                               0
# is_applied_social_sciences                                             0
# is_biological_sciences                                                 0
# is_engineering                                                         1
# is_exact_earth_sciences                                                0
# is_health_sciences                                                     0
# is_human_sciences                                                      0
# is_linguistics_letters_arts                                            0
# is_multidisciplinary                                                   0
# title_current_status                                             current
# pid_scielo                                       S2446-47402018000300211
# doc_publishing_year                                                 2018
# doc_type                                                research-article
# doc_is_citable                                                         1
# doc_affiliation_instituition      Universidade Federal do Rio de Janeiro
# doc_affiliation_country                                           Brazil
# doc_affiliation_country_iso_3166                                      BR
# doc_affiliation_state                                     Rio de Janeiro
# doc_affiliation_city                                      Rio de Janeiro

# %%
doc_authors.tail(2).T
# Out:
#                                                                1437245  \
# extraction_date                                             2018-11-10
# study_unit                                                    document
# collection                                                         scl
# issn_scielo                                                  2446-4740
# issns                                              2446-4732;2446-4740
# title_scielo                        Research on Biomedical Engineering
# title_thematic_areas                                       Engineering
# is_agricultural_sciences                                             0
# is_applied_social_sciences                                           0
# is_biological_sciences                                               0
# is_engineering                                                       1
# is_exact_earth_sciences                                              0
# is_health_sciences                                                   0
# is_human_sciences                                                    0
# is_linguistics_letters_arts                                          0
# is_multidisciplinary                                                 0
# title_current_status                                           current
# pid_scielo                                     S2446-47402018000300211
# doc_publishing_year                                               2018
# doc_type                                              research-article
# doc_is_citable                                                       1
# doc_author                                        Luiz Alberto Batista
# doc_author_institution          Universidade Federal do Rio de Janeiro
# doc_author_affiliation_country                                  Brazil
# doc_author_affiliation_state                            Rio de Janeiro
# doc_author_affiliation_city                             Rio de Janeiro
#
#                                                                1437246
# extraction_date                                             2018-11-10
# study_unit                                                    document
# collection                                                         scl
# issn_scielo                                                  2446-4740
# issns                                              2446-4732;2446-4740
# title_scielo                        Research on Biomedical Engineering
# title_thematic_areas                                       Engineering
# is_agricultural_sciences                                             0
# is_applied_social_sciences                                           0
# is_biological_sciences                                               0
# is_engineering                                                       1
# is_exact_earth_sciences                                              0
# is_health_sciences                                                   0
# is_human_sciences                                                    0
# is_linguistics_letters_arts                                          0
# is_multidisciplinary                                                 0
# title_current_status                                           current
# pid_scielo                                     S2446-47402018000300211
# doc_publishing_year                                               2018
# doc_type                                              research-article
# doc_is_citable                                                       1
# doc_author                                              Jurandir Nadal
# doc_author_institution          Universidade Federal do Rio de Janeiro
# doc_author_affiliation_country                                  Brazil
# doc_author_affiliation_state                            Rio de Janeiro
# doc_author_affiliation_city                             Rio de Janeiro

# %% [markdown]
# There are much more info in `doc_authors`.

# %% [markdown]
# Let's get all the instituition names:

# %%
all_names = set(doc_affs["doc_affiliation_instituition"].dropna()) \
    .union(doc_authors["doc_author_institution"].dropna())
len(all_names)
# Out:
# 60437

# %% [markdown]
# ## USP

# %% [markdown]
# The following names have either the "`usp`" substring
# or something like the university name:

# %%
usp_regex = "usp|(university\s+of|univ(ersidade?)?(\s*de)?)\s+(s[aãÃ]o|s\.)\s+paulo"
names_with_usp = {name for name in all_names
                  if re.search(usp_regex, name.lower())}
names_with_usp
# Out:
# {' Departamento de Entomologia, Fitopatologia e Zoologia Agrícola, Escola Superior de Agricultura "Luiz de Queiroz", Universidade de São Paulo',
#  ' Departamento de Genética e Biologia Evolutiva, Instituto de Biociências, Universidade de São Paulo',
#  ' Departamento de Genética e Biologia Evolutiva, Universidade de São Paulo',
#  ' Departamento de Genética, Escola Superior de Agricultura Luiz de Queiroz, Universidade de São Paulo',
#  ' Laboratório de Ecotoxicologia Marinha, Instituto Oceanográfico, Universidade de São Paulo',
#  ', Universidade de São Paulo',
#  '-ESALQ/USP',
#  '-FMUSP',
#  '/USP',
#  '/Universidade de São Paulo',
#  'Ambulatório Geral do Instituto da Criança - HCFMUSP',
#  'Anhanguera University of São Paulo',
#  'Bandeirante University of São Paulo',
#  'Campus USP',
#  'Catholic University of São Paulo',
#  'Clínicas da Faculdade de Medicina da Universidade de São Paulo (IOT-HCFMUSP)',
#  'Comissão de Publicações da FEUSP',
#  'Departamento de Ciência Política da USP',
#  'Departamento de Farmacologia do Instituto de Ciencias Biomedicas da Universidade de Sao Paulo',
#  'Departamento de Psiquiatria da FMUSP',
#  'Divisao de Anestesiologia do Hospital das Clinicas HCFMUSP',
#  'ECA - USP',
#  'ECA-USP',
#  'EDUSP',
#  'EEUSP',
#  'EPUSP',
#  'ESALQ/ USP',
#  'ESALQ/USP',
#  'Editora da Universidade de São Paulo',
#  'Escola Politécnica - PTR-EPUSP',
#  'Escola Politécnica da USP',
#  'Escola Politécnica da Universidade de S. Paulo',
#  'Escola Politécnica da Universidade de São Paulo',
#  "Escola Superior de Agricultura 'Luiz de Queiroz', Universidade de São Paulo",
#  'Escola de Enfermagem de Ribeirão Preto da Universidade de São Paulo',
#  'FCF/FEA/FSP-USP',
#  'FCFRP-USP',
#  'FCFUSP',
#  'FEA USP',
#  'FEA-USP',
#  'FEAUSP',
#  'FFLCH-USP',
#  'FFLCH/USP',
#  'FMUSP',
#  'FMVZ/USP',
#  'FO-USP',
#  'FORP-USP',
#  'FORP/USP',
#  'FSPUSP',
#  'Faculdade de Ciencias Farmaceuticas da Universidade de Sao Paulo',
#  'Faculdade de Economia, Administração e Contabilidade da USP',
#  'Faculdade de Educação da Universidade de São Paulo',
#  'Faculdade de Filosofia, Letras e Ciências Humanas da USP',
#  'Faculdade de Medicina Universidade de São Paulo',
#  'Faculdade de Medicina Veterinária e Zootecnia da Universidade de São Paulo',
#  'Faculdade de Medicina da Pontifícia Universidade de São Paulo',
#  'Faculdade de Medicina da USP',
#  'Faculdade de Medicina da Universidade São Paulo',
#  'Faculdade de Medicina da Universidade de São Paulo',
#  'Faculdade de Medicina da Universidade de São Paulo (FMUSP)',
#  'Faculdade de Medicina da Universidade de São PauloDisciplina de Obstetrícia',
#  'Faculdade de Medicina de Ribeirão Preto -USP',
#  'Faculdade de Medicina de Ribeirão Preto da Universidade de São Paulo',
#  'Faculdade de Medicina de Ribeirão Preto-USP',
#  'Faculdade de Medicina de Riberão Preto, Universidade de São Paulo',
#  'Faculdade de Medicina, Universidade de Sao Paulo',
#  'Faculdade de Odontologia da Universidade de São Paulo',
#  'Faculdade de Odontologia de Bauru da Universidadede São Paulo',
#  'Faculdade de Saude Publica da Universidade de Sao Paulo',
#  'Faculdade de Saúde Pública da Universidade de São Paulo',
#  'Federal University of Sao Paulo',
#  'Federal University of São Paulo',
#  'Federal University of São Paulo|Santa Casa de Misericórdia de São Paulo/OSS',
#  'HC-FMUSP',
#  'HCFMUSP',
#  'Hospital das Clínicas da Faculdade de Medicina da Universidade de São Paulo',
#  'Hospital das Clínicas da Faculdade de Medicina da Universidade de São Paulo (HC-FMUSP)',
#  'Hospital das Clínicas da Faculdade de Medicina da Universidade de São Paulo (HCFMUSP)',
#  'Hospital das Clínicas of the University of São Paulo School of Medicine',
#  'IEB/USP',
#  'IOUSP',
#  'IPUSP',
#  'IPq-HCFMUSP',
#  'Incor-FMUSP',
#  'Institute of Psychiatry, Universidade de São Paulo (USP)',
#  'Instituto Oceanográfico da Universidade de São Paulo',
#  'Instituto de Estudos Avançados da USP',
#  'Instituto de Física da Universidade de São Paulo',
#  'Instituto de Física de São Carlos-USP',
#  'Instituto de Geociências da USP',
#  'Instituto de Psicologia - USP',
#  'Instituto de Psicologia da USP',
#  'Laboratório de Investigação Médica da FMUSP - LIM',
#  'Medicine Faculty of University of São Paulo',
#  'Medicine Federal University of São Paulo',
#  'Methodist University of Sao Paulo',
#  'Methodist University of São Paulo',
#  'Museu de Zoologia da Universidade de São Paulo',
#  'Núcleo de Estudo da Violência (NEV-USP)',
#  'POLI-USP',
#  'POLI-USP.',
#  'PUC/USP',
#  'Política pela Universidade de São Paulo',
#  'Pontifícia Universidade de São Paulo',
#  'RAUSP',
#  'Revista USP',
#  'State University of São Paulo',
#  'State University of São Paulo (Júlio de Mesquita Filho)',
#  'State University of São Paulo - “Julio de Mesquita Filho”',
#  'The University of São Paulo Medical School',
#  'USP',
#  'USP - Piracicaba, SP',
#  'USP - Pirassununga',
#  'USP - Ribeirão Preto',
#  'USP - São Carlos',
#  'USP - University of Sao Paulo',
#  'USP RP',
#  'USP São Carlos',
#  'USP de Ribeirão Preto',
#  'USP, Ribeirão Preto,Faculdade de Medicina',
#  'USP,Centro de Cooperação de Atividades Especiais',
#  'USP,Coordenadoria de Assistência Social (COSEAS)',
#  'USP,Departamento de Administração Escolar e Economia da Educação da Faculdade de Educação',
#  'USP,Departamento de Filosofia da Educação e Ciências da Educação da Faculdade de Educação',
#  'USP,Departamento de Microbiologia,  ICB2',
#  'USP,Escola de Comunicações e Artes',
#  'USP,Faculdade de Filosofia, Letras e Ciências Humanas',
#  'USP,Instituto Butantã',
#  'USP,Instituto de Biociências',
#  'USP,Instituto de Eletrotécnica e Energia',
#  'USP,Instituto de Estudos Avançados',
#  'USP,Instituto de Física',
#  'USP,Instituto de Psicologia',
#  'USP,Instituto do Coração',
#  'USP-Ribeirão Preto',
#  'USP-SP',
#  'USP-São Carlos',
#  'USP/Bauru',
#  'USP/ESALQ',
#  'USP/Leste',
#  'USP/Ribeirão Preto',
#  'USP/São Paulo',
#  'USPI',
#  'USPMS',
#  'Univ S. Paulo',
#  'Univ de São Paulo',
#  'Univ de São Paulo - USP',
#  'Universidad de São Paulo',
#  'Universidade  de São Paulo,Instituto  de Estudos Avançados',
#  'Universidade De São Paulo',
#  'Universidade São Paulo',
#  'Universidade Universidade de São Paulo',
#  'Universidade de S. Paulo',
#  'Universidade de Sao Paulo',
#  'Universidade de Sao Paulo & CICAP- Patologia, Hospital Alemao Oswaldo Cruz',
#  'Universidade de Sao Paulo Sao Paulo',
#  'Universidade de São Paulo',
#  'Universidade de São Paulo (FMUSP)',
#  'Universidade de São Paulo (USP)',
#  'Universidade de São Paulo (USP), Ribeirão Preto',
#  'Universidade de São Paulo (USP),Departamento de Antropologia',
#  'Universidade de São Paulo (USP),Departamento de Ciência Política',
#  'Universidade de São Paulo (USP),Departamento de Sociologia',
#  'Universidade de São Paulo - Ribeirão Preto',
#  'Universidade de São Paulo - USP',
#  'Universidade de São Paulo Faculdade de Medicina',
#  'Universidade de São Paulo RP',
#  'Universidade de São Paulo São Carlos',
#  'Universidade de São Paulo São Paulo',
#  'Universidade de São Paulo at Ribeirão Preto',
#  'Universidade de São Paulo – USP',
#  'Universidade de São Paulo,',
#  'Universidade de São Paulo, (USP)',
#  'Universidade de São Paulo, ,',
#  'Universidade de São Paulo, Faculdade de Agricultura “Luiz de Queiroz”',
#  'Universidade de São Paulo, São Paulo',
#  'Universidade de São Paulo,Departamento de Parasitologia, Laboratório de Epidemiologia Genética, Instituto de Ciências Biomédicas',
#  'Universidade de São Paulo,Departamento de Sociologia',
#  'Universidade de São Paulo,Faculdade de Filosofia, Letras e Ciências Humanas',
#  'Universidade de São Paulo,Instituto de Ciências Matemáticas e de Computação',
#  'Universidade de São Paulo-',
#  'Universidade de São Paulo-RP',
#  'Universidade de São Paulo/',
#  'Universidade de São paulo',
#  'Universidade de Universidade de São Paulo',
#  'Universidade de são Paulo',
#  'Universidadede São Paulo',
#  'University of Sao Paulo',
#  'University of Sao Paulo USP',
#  'University of Sao Paulo at Ribeirao Preto',
#  'University of São Paulo',
#  'University of São Paulo (USP)',
#  'University of São Paulo - USP',
#  'University of São Paulo Medical School',
#  'University of São Paulo School of Medicine',
#  'University of São Paulo – USP',
#  'University of São Paulo – USP.',
#  'University of São Paulo, School of Engineering of São Carlos',
#  'University of São Paulo,Department of Biochemistry',
#  'University of São Paulo,Department of Biochemistry, School of Medicine',
#  'University of São Paulo,Institute of Physics of São Carlos',
#  'University of São Paulo,Laboratory of Crystallography, Institute of Physics of São Carlos',
#  'University of São Paulo-USP',
#  'University of São Paulo/ESALQ',
#  'da Universidade de São Paulo',
#  'universidade de São Paulo',
#  'universidade de são paulo',
#  'usp'}

# %% [markdown]
# Only these aren't from the University of São Paulo
# (sometimes `São` appears without the tilde,
#  some of them appear more than once because of other neighboring words):
#
# * `Anhanguera University of São Paulo`
# * `Bandeirante University of São Paulo`
# * `Catholic University of São Paulo`
# * `Federal University of São Paulo`
# * `Methodist University of São Paulo`
# * `Pontifícia Universidade de São Paulo`
# * `USPMS` (US Petroleum Marine Services)
#
# Besides `PUC/USP`, which isn't a valid name,
# though it's explicit in the [article PDF](
#   http://w.scielo.br/pdf/rlae/v7n2/13461.pdf
# ).
# It could be a typo of `PUC/SP` (*Pontifícia Universidade Católica*/São Paulo)
# but the author's Lattes CV/resumé tells us that her Ph.D. degree was at UNIFESP,
# not USP or PUC/SP. Either way, we're just looking for USP entries for now,
# so there should be no more worries regarding this entry.

# %%
doc_authors[doc_authors["pid_scielo"].isin(
    doc_authors[doc_authors["doc_author_institution"] == "PUC/USP"]["pid_scielo"]
)].T
# Out:
#                                                                      178925  \
# extraction_date                                                  2018-11-10
# study_unit                                                         document
# collection                                                              scl
# issn_scielo                                                       0104-1169
# issns                                                             1518-8345
# title_scielo                         Revista Latino-Americana de Enfermagem
# title_thematic_areas                                        Health Sciences
# is_agricultural_sciences                                                  0
# is_applied_social_sciences                                                0
# is_biological_sciences                                                    0
# is_engineering                                                            0
# is_exact_earth_sciences                                                   0
# is_health_sciences                                                        1
# is_human_sciences                                                         0
# is_linguistics_letters_arts                                               0
# is_multidisciplinary                                                      0
# title_current_status                                                current
# pid_scielo                                          S0104-11691999000200007
# doc_publishing_year                                                    1999
# doc_type                                                   research-article
# doc_is_citable                                                            1
# doc_author                                     Gilson de Vasconcelos Torres
# doc_author_institution          Universidade Federal do Rio Grande do Norte
# doc_author_affiliation_country                                       Brazil
# doc_author_affiliation_state                            Rio Grande do Norte
# doc_author_affiliation_city                                             NaN
#
#                                                                 178926  \
# extraction_date                                             2018-11-10
# study_unit                                                    document
# collection                                                         scl
# issn_scielo                                                  0104-1169
# issns                                                        1518-8345
# title_scielo                    Revista Latino-Americana de Enfermagem
# title_thematic_areas                                   Health Sciences
# is_agricultural_sciences                                             0
# is_applied_social_sciences                                           0
# is_biological_sciences                                               0
# is_engineering                                                       0
# is_exact_earth_sciences                                              0
# is_health_sciences                                                   1
# is_human_sciences                                                    0
# is_linguistics_letters_arts                                          0
# is_multidisciplinary                                                 0
# title_current_status                                           current
# pid_scielo                                     S0104-11691999000200007
# doc_publishing_year                                               1999
# doc_type                                              research-article
# doc_is_citable                                                       1
# doc_author                                Gilson de Vasconcelos Torres
# doc_author_institution                       Universidade de São Paulo
# doc_author_affiliation_country                                     NaN
# doc_author_affiliation_state                                       NaN
# doc_author_affiliation_city                                        NaN
#
#                                                                      178927  \
# extraction_date                                                  2018-11-10
# study_unit                                                         document
# collection                                                              scl
# issn_scielo                                                       0104-1169
# issns                                                             1518-8345
# title_scielo                         Revista Latino-Americana de Enfermagem
# title_thematic_areas                                        Health Sciences
# is_agricultural_sciences                                                  0
# is_applied_social_sciences                                                0
# is_biological_sciences                                                    0
# is_engineering                                                            0
# is_exact_earth_sciences                                                   0
# is_health_sciences                                                        1
# is_human_sciences                                                         0
# is_linguistics_letters_arts                                               0
# is_multidisciplinary                                                      0
# title_current_status                                                current
# pid_scielo                                          S0104-11691999000200007
# doc_publishing_year                                                    1999
# doc_type                                                   research-article
# doc_is_citable                                                            1
# doc_author                                       Rejane Marie Barbosa Davim
# doc_author_institution          Universidade Federal do Rio Grande do Norte
# doc_author_affiliation_country                                       Brazil
# doc_author_affiliation_state                            Rio Grande do Norte
# doc_author_affiliation_city                                             NaN
#
#                                                                 178928  \
# extraction_date                                             2018-11-10
# study_unit                                                    document
# collection                                                         scl
# issn_scielo                                                  0104-1169
# issns                                                        1518-8345
# title_scielo                    Revista Latino-Americana de Enfermagem
# title_thematic_areas                                   Health Sciences
# is_agricultural_sciences                                             0
# is_applied_social_sciences                                           0
# is_biological_sciences                                               0
# is_engineering                                                       0
# is_exact_earth_sciences                                              0
# is_health_sciences                                                   1
# is_human_sciences                                                    0
# is_linguistics_letters_arts                                          0
# is_multidisciplinary                                                 0
# title_current_status                                           current
# pid_scielo                                     S0104-11691999000200007
# doc_publishing_year                                               1999
# doc_type                                              research-article
# doc_is_citable                                                       1
# doc_author                                Maria Miriam Lima da Nóbrega
# doc_author_institution                                            UFPB
# doc_author_affiliation_country                                     NaN
# doc_author_affiliation_state                                       NaN
# doc_author_affiliation_city                                        NaN
#
#                                                                 178929
# extraction_date                                             2018-11-10
# study_unit                                                    document
# collection                                                         scl
# issn_scielo                                                  0104-1169
# issns                                                        1518-8345
# title_scielo                    Revista Latino-Americana de Enfermagem
# title_thematic_areas                                   Health Sciences
# is_agricultural_sciences                                             0
# is_applied_social_sciences                                           0
# is_biological_sciences                                               0
# is_engineering                                                       0
# is_exact_earth_sciences                                              0
# is_health_sciences                                                   1
# is_human_sciences                                                    0
# is_linguistics_letters_arts                                          0
# is_multidisciplinary                                                 0
# title_current_status                                           current
# pid_scielo                                     S0104-11691999000200007
# doc_publishing_year                                               1999
# doc_type                                              research-article
# doc_is_citable                                                       1
# doc_author                                Maria Miriam Lima da Nóbrega
# doc_author_institution                                         PUC/USP
# doc_author_affiliation_country                                     NaN
# doc_author_affiliation_state                                       NaN
# doc_author_affiliation_city                                        NaN

# %% [markdown]
# The only entry that remains strange is `USPI`,
# which seems to be a typo for `USP`.

# %%
doc_authors[doc_authors["pid_scielo"].isin(
    doc_authors[doc_authors["doc_author_institution"] == "USPI"]["pid_scielo"]
)].T
# Out:
#                                                           942280  \
# extraction_date                                       2018-11-10
# study_unit                                              document
# collection                                                   scl
# issn_scielo                                            0103-166X
# issns                                        0103-166X;1982-0275
# title_scielo                    Estudos de Psicologia (Campinas)
# title_thematic_areas                              Human Sciences
# is_agricultural_sciences                                       0
# is_applied_social_sciences                                     0
# is_biological_sciences                                         0
# is_engineering                                                 0
# is_exact_earth_sciences                                        0
# is_health_sciences                                             0
# is_human_sciences                                              1
# is_linguistics_letters_arts                                    0
# is_multidisciplinary                                           0
# title_current_status                                     current
# pid_scielo                               S0103-166X2000000200001
# doc_publishing_year                                         2000
# doc_type                                        research-article
# doc_is_citable                                                 1
# doc_author                                   Edilaine dos Santos
# doc_author_institution                                      USPI
# doc_author_affiliation_country                               NaN
# doc_author_affiliation_state                                  SP
# doc_author_affiliation_city                                Bauru
#
#                                                           942281  \
# extraction_date                                       2018-11-10
# study_unit                                              document
# collection                                                   scl
# issn_scielo                                            0103-166X
# issns                                        0103-166X;1982-0275
# title_scielo                    Estudos de Psicologia (Campinas)
# title_thematic_areas                              Human Sciences
# is_agricultural_sciences                                       0
# is_applied_social_sciences                                     0
# is_biological_sciences                                         0
# is_engineering                                                 0
# is_exact_earth_sciences                                        0
# is_health_sciences                                             0
# is_human_sciences                                              1
# is_linguistics_letters_arts                                    0
# is_multidisciplinary                                           0
# title_current_status                                     current
# pid_scielo                               S0103-166X2000000200001
# doc_publishing_year                                         2000
# doc_type                                        research-article
# doc_is_citable                                                 1
# doc_author                               Carmen Maria Bueno Neme
# doc_author_institution            Universidade Estadual Paulista
# doc_author_affiliation_country                            Brazil
# doc_author_affiliation_state                           São Paulo
# doc_author_affiliation_city                                Bauru
#
#                                                           942282
# extraction_date                                       2018-11-10
# study_unit                                              document
# collection                                                   scl
# issn_scielo                                            0103-166X
# issns                                        0103-166X;1982-0275
# title_scielo                    Estudos de Psicologia (Campinas)
# title_thematic_areas                              Human Sciences
# is_agricultural_sciences                                       0
# is_applied_social_sciences                                     0
# is_biological_sciences                                         0
# is_engineering                                                 0
# is_exact_earth_sciences                                        0
# is_health_sciences                                             0
# is_human_sciences                                              1
# is_linguistics_letters_arts                                    0
# is_multidisciplinary                                           0
# title_current_status                                     current
# pid_scielo                               S0103-166X2000000200001
# doc_publishing_year                                         2000
# doc_type                                        research-article
# doc_is_citable                                                 1
# doc_author                                Liliam D'Aquino Tavano
# doc_author_institution                 Universidade de São Paulo
# doc_author_affiliation_country                            Brazil
# doc_author_affiliation_state                           São Paulo
# doc_author_affiliation_city                                Bauru

# %% [markdown]
# There are some typos for the university names,
# but we should be careful when looking for similar names.

# %%
usp_fuzzy_regex = (
    "((university\s+of|universidade?(\s*de)?)\s+(s[aãÃ]o|s\.)\s+paulo"
    "|(s[aãÃ]o|s\.)\s+paulo university"
    "){e<=3}"
)
other_names_with_usp = {name for name in all_names - names_with_usp
                        if regex.search(usp_fuzzy_regex, name.lower())}
other_names_with_usp
# Out:
# {'City of Sao Paulo University',
#  'City of São Paulo University',
#  'Clinical Hospital of São Paulo University',
#  'De Paul University',
#  'Federal University of S. Carlos',
#  'Federal University of Sao Carlos',
#  'Federal University of São Carlos',
#  'Federal University of São Carlos – UFSCar',
#  'Federal University of São Carlos,Department of Physiological Sciences',
#  'Federal University of São Carlos,Laboratory of Neurosciences, Department of Physiotherapy',
#  'Nove de Julho University, São Paulo',
#  'Sao Camilo University Center',
#  'Sao Paulo University',
#  'São Camilo University Center',
#  'São Paulo University',
#  'São Paulo University Medical',
#  'São Paulo University Medical School',
#  'São Paulo University School of Medicine',
#  'São Paulo University of Pharmaceutical Sciences',
#  'São Paulo Univesity',
#  'Univeridade de São Paulo',
#  'Univers, de S. Paulo',
#  'Universiade de São Paulo',
#  'Universidad San Pablo CEU',
#  'Universidad de San Carlos',
#  'Universidad de San Carlos de Guatemala',
#  'Universidad de San Pablo',
#  'Universidada de São Paulo',
#  'Universidade Federal de São Paulo, Universidade Federal de São Paulo',
#  'Universidade São Camilo',
#  'Universidade São Marcos',
#  'Universidade d São Paulo',
#  'Universidade da São Paulo',
#  'Universidade de So Paulo',
#  'Universidade de SÃ£o Paulo',
#  'Universidade de Sâo Paulo',
#  'Universidade de São Camilo',
#  'Universidade de São Carlos',
#  'Universidade de São Marcos',
#  'Universidade de São Paul',
#  'Universidade de Säo Paulo',
#  'Universidade of São Paulo',
#  'Universidsade de São Paulo',
#  'University São Paulo',
#  'University of San Carlos',
#  'University of San Paolo',
#  'University os São Paulo',
#  'Univesidade de São Paulo',
#  'niversidade de São Paulo'}

# %% [markdown]
# There are some names that clearly regards to other university,
# like *Universidad Católica San Pablo* (CEU).
# Names like *Camilo*, *Carlos*, *Marcos* or *Pablo* aren't *Paulo*.
# Again, USP isn't a national/federal university,
# and *City of São Paulo University* reads like UNICID, not USP.

# %%
def has_none_of(text, avoidance_list):
    lower_text = text.lower()
    return all((el not in lower_text) for el in avoidance_list)

# %%
not_paulo = ["city", "federal", "camilo", "carlos", "marcos", "pablo", "julho", "de paul"]
typoed_usp = {name for name in other_names_with_usp if has_none_of(name, not_paulo)}
typoed_usp
# Out:
# {'Clinical Hospital of São Paulo University',
#  'Sao Paulo University',
#  'São Paulo University',
#  'São Paulo University Medical',
#  'São Paulo University Medical School',
#  'São Paulo University School of Medicine',
#  'São Paulo University of Pharmaceutical Sciences',
#  'São Paulo Univesity',
#  'Univeridade de São Paulo',
#  'Univers, de S. Paulo',
#  'Universiade de São Paulo',
#  'Universidada de São Paulo',
#  'Universidade d São Paulo',
#  'Universidade da São Paulo',
#  'Universidade de So Paulo',
#  'Universidade de SÃ£o Paulo',
#  'Universidade de Sâo Paulo',
#  'Universidade de São Paul',
#  'Universidade de Säo Paulo',
#  'Universidade of São Paulo',
#  'Universidsade de São Paulo',
#  'University São Paulo',
#  'University of San Paolo',
#  'University os São Paulo',
#  'Univesidade de São Paulo',
#  'niversidade de São Paulo'}

# %%
not_usp = ["state", "anhanguera", "bandeirante", "catholic",
           "federal", "methodist", "pontifícia", "uspms"]
usp_names = {
    name for name in names_with_usp
         if has_none_of(name, not_usp)
}.union(typoed_usp)
len(usp_names)
# Out:
# 219

# %% [markdown]
# ## UNESP

# %%
unesp_regex = (
    "unesp"
    "|universidade?\s*esta(du|t)al\s*paulista"
    "|j[uúÚ]lio.*mesquita\s+filho"
    "|(s[aãÃ]o|s\.)\s*paulo\s*state\s*university"
    "|state.*(s[aãÃ]o|s\.)\s*paulo\s*university"
)
names_with_unesp = {name for name in all_names - usp_names
                    if re.search(unesp_regex, name.lower())}
names_with_unesp
# Out:
# {' Núcleo de Estudos em Poluição e Ecotoxicologia Aquática, Universidade Estadual Paulista',
#  'Bióloga (UNESP/Botucatu)',
#  'CEVAP-UNESP',
#  'Campus de Botucatu - UNESP,Departamento de Doenças Tropicais e Diagnóstico por Imagem - Faculdade de Medicina de Botucatu',
#  'Doutor wsaad@fmb.unesp.br',
#  'FCA-UNESP',
#  'FCA/UNESP Fazenda Experimental Lajeado',
#  'FCAV-Unesp',
#  'FCAV/UNESP',
#  'FMUNESP',
#  'Faculdade de Ciências e Tecnologia, UNESP',
#  'Faculdade de Medicina - UNESP',
#  'Faculdade de Odontologia de Araraquara - Unesp',
#  'IB-UNESP',
#  'IBUNESP',
#  'IIUniversidade Estadual Paulista',
#  'Light SESA/UNESP',
#  'Paulista State University ?Julio de Mesquita Filho?',
#  'Sao Paulo State University',
#  'Sao Paulo State University Júlio de Mesquita Filho',
#  'School of Dentistry, São Paulo State University',
#  'School of São Paulo State University Julio de Mesquita Filho',
#  'State University of São Paulo (Júlio de Mesquita Filho)',
#  'State University of São Paulo - “Julio de Mesquita Filho”',
#  'São Paulo State São Paulo State University',
#  'São Paulo State University',
#  'São Paulo State University "Júlio de Mesquita Filho"',
#  'São Paulo State University "Júlio de Mesquita Filho" (UNESP)',
#  'São Paulo State University (UNESP - Univ Estadual Paulista)',
#  'São Paulo State University (UNESP)',
#  'São Paulo State University (UNESP) at Araraquara',
#  'São Paulo State University (UNESP) at Botucatu',
#  'São Paulo State University - UNESP',
#  'São Paulo State University Guaratinguetá',
#  'São Paulo State University Julio de Mesquita Filho',
#  'São Paulo State University,Center for the Study of Venoms and Venomous Animals',
#  'São Paulo State University,Department of Physics, Institute of Biosciences, Humanities and Physical Sciences',
#  'São Paulo State University,School of Medicine of Botucatu',
#  'São Paulo State University-UNESP',
#  'São Paulo State University/FCA',
#  'São Paulo State University/FCAT',
#  'UNESP',
#  'UNESP - Botucatu',
#  'UNESP - Jaboticabal',
#  'UNESP - Rio Claro',
#  'UNESP - São José dos Campos',
#  'UNESP - Universidade Estadual Paulista',
#  'UNESP - Universidade Estadual Paulista Júlio de Mesquita Filho',
#  'UNESP, Campus of Araçatuba',
#  'UNESP, Campus of Botucatu',
#  'UNESP, São Paulo State University, Botucatu, SP, Brazil.',
#  'UNESP,CEVAP',
#  'UNESP,Departamento de Biologia do Instituto de Biociências',
#  'UNESP- Univ Estadual Paulista',
#  'UNESP-Araraquara',
#  'UNESP-FCA',
#  'UNESP-Ilha Solteira',
#  'UNESP-Jaboticabal',
#  'UNESP/Araraquara',
#  'UNESP/Botucatu',
#  'UNESP/FCAV',
#  'Unesp',
#  'Unesp - Campus de Marília',
#  'Unesp - Universidade Estadual Paulista',
#  'Unesp Araraquara',
#  'Unesp Campus de Marília',
#  'Unesp, Assis',
#  'Unesp, Campus de Araçatuba',
#  'Unesp-Botucatu',
#  'Unesp-Campus de Botucatu',
#  'Unesp-Campus de Jaboticabal',
#  'Unesp-Jaboticabal',
#  'Unesp-Marília',
#  'Unesp/Bauru',
#  'Unesp/Franca',
#  'Unesp/Ibilce',
#  'Unesp/Marília',
#  'Unespar',
#  'Universidade Estadual "Julio de Mesquita Filho"',
#  'Universidade Estadual Julio Mesquita Filho',
#  'Universidade Estadual Júlio de Mesquita Filho',
#  'Universidade Estadual Paulista',
#  'Universidade Estadual Paulista " Júlio de Mesquita Filho "',
#  'Universidade Estadual Paulista "Júlio de Mesquita Filho"',
#  "Universidade Estadual Paulista 'Julio Mesquista Filho'",
#  "Universidade Estadual Paulista 'Júlio Mesquita Filho'",
#  "Universidade Estadual Paulista 'Júlio de Mesquita Filho'",
#  'Universidade Estadual Paulista (UNESP)',
#  'Universidade Estadual Paulista - Assis',
#  'Universidade Estadual Paulista - Campus de Assis',
#  'Universidade Estadual Paulista - Rio Claro',
#  'Universidade Estadual Paulista - UNESP',
#  'Universidade Estadual Paulista - UNESP <p ALIGN=',
#  'Universidade Estadual Paulista - Unesp -, Campus Franca',
#  'Universidade Estadual Paulista José de Mesquita Filho',
#  'Universidade Estadual Paulista Julio Mesquita Filho',
#  'Universidade Estadual Paulista Julio de Mesquita',
#  'Universidade Estadual Paulista Julio de Mesquita Filho',
#  'Universidade Estadual Paulista Julio de Mesquita filho',
#  'Universidade Estadual Paulista JÃºlio de Mesquita Filho',
#  'Universidade Estadual Paulista Júlio Mesquita Filho',
#  'Universidade Estadual Paulista Júlio Mesquita Filho UNESP',
#  'Universidade Estadual Paulista Júlio de Mesquita',
#  'Universidade Estadual Paulista Júlio de Mesquita Filho',
#  'Universidade Estadual Paulista Júlio de Mesquita Filho (UNESP)',
#  'Universidade Estadual Paulista Júlio de Mesquita Filho - UNESP',
#  'Universidade Estadual Paulista Júlio de Mesquita Filho – UNESP',
#  'Universidade Estadual Paulista Paulista Júlio de Mesquita Filho',
#  'Universidade Estadual Paulista de Assis',
#  'Universidade Estadual Paulista de Botucatu',
#  'Universidade Estadual Paulista de Jaboticabal',
#  'Universidade Estadual Paulista – UNESP',
#  'Universidade Estadual Paulista ‘Julio Mesquita Filho’',
#  'Universidade Estadual Paulista ‘Júlio Mesquita Filho’',
#  'Universidade Estadual Paulista ‘Júlio de Mesquita Filho’',
#  'Universidade Estadual Paulista ’Júlio de Mesquita Filho’',
#  'Universidade Estadual Paulista “Júlio de Mesquita Filho”',
#  'Universidade Estadual Paulista,',
#  'Universidade Estadual Paulista, Araraquara',
#  'Universidade Estadual Paulista, Araçatuba',
#  'Universidade Estadual Paulista, Assis,Faculdade de Ciências e Letras',
#  'Universidade Estadual Paulista, Campus Jaboticabal',
#  'Universidade Estadual Paulista, Rio Claro',
#  'Universidade Estadual Paulista, São José do Rio Preto',
#  'Universidade Estadual Paulista, Unesp',
#  'Universidade Estadual Paulista, Universidade Estadual Paulista',
#  'Universidade Estadual Paulista-UNESP e Prefeitura da Estância Turística e Religiosa de Aparecida (SP)-PETRA,Departamento de Zoología do Instituto de Biosciências de Botucatu',
#  'Universidade Estadual Paulista. UNESP - Franca',
#  'Universidade Estadual Paulista/UNESP',
#  'Universidade Estadual Paulista/Unesp',
#  'Universidade Estadual Paulistana',
#  'Universidade Estadual de São Paulo (UNESP)',
#  'Universidade Estadual de São Paulo - UNESP',
#  'Universidade Estadual de São Paulo Julio Mesquita Filho',
#  'Universidade Estadual do Paraná (UNESPAR)',
#  'Universidade Estadual do Paraná/ UNESPAR',
#  'Universidade Estadual paulista',
#  'Universidade Paulista Julio de Mesquita Filho',
#  'Universidade Universidade Estadual Paulista ( UNESP)',
#  'Universidade do Estado de São Paulo (UNESP)',
#  'University of Agrarian and Veterinary Sciences of UNESP',
#  '“Júlio de Mesquita Filho” State University'}

# %% [markdown]
# Here the only names that don't regard to UNESP are the UNESPAR (3 entries).

# %%
unesp_fuzzy_regex = (
    "(universidade?\s*esta(du|t)al\s*paulista"
    "|j[uúÚ]lio.*mesquita\s+filho"
    "|(s[aãÃ]o|s\.)\s*paulo\s*state\s*university"
    "|state.*(s[aãÃ]o|s\.)\s*paulo\s*university"
    "){e<=3}"
)
other_names_with_unesp = {name for name in all_names - names_with_unesp - usp_names
                          if regex.search(unesp_fuzzy_regex, name.lower())}
other_names_with_unesp
# Out:
# {'Univerisidade Estadual Paulista',
#  'Universdiade Estadual Paulista',
#  'Universidad Estatal a Distancia',
#  'Universidad Estatal a Distancia de Costa Rica',
#  'Universidade Estadual Paupsta',
#  'Universidade Estadula Paulista',
#  'Universidade Estatal a Distancia, Sistema de estúdios de Posgrado',
#  'Universidade Julio de Mequita Filho',
#  'Univesidade Estadual Paulista',
#  'Unuiversidade Estadual Paulista',
#  'niversidade Estadual Paulista'}

# %% [markdown]
# UNESP have nothing to do with these entries with the word "`Distancia`".

# %%
typoed_unesp = {name for name in other_names_with_unesp if "distancia" not in name.lower()}
typoed_unesp
# Out:
# {'Univerisidade Estadual Paulista',
#  'Universdiade Estadual Paulista',
#  'Universidade Estadual Paupsta',
#  'Universidade Estadula Paulista',
#  'Universidade Julio de Mequita Filho',
#  'Univesidade Estadual Paulista',
#  'Unuiversidade Estadual Paulista',
#  'niversidade Estadual Paulista'}

# %%
unesp_names = {
    name for name in names_with_unesp
         if "unespar" not in name.lower()
}.union(typoed_unesp)
len(unesp_names)
# Out:
# 147
