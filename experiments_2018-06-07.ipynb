# %% [markdown]
# # CSV data analysis

# %% [markdown]
# During the last monday (`2018-06-04`), a CSV table was generated from a XML dataset containing $23821$ files. From these, $425$ had been proven unreadable by the `lxml` parser, and they've been discarded. Some of the remaining $23396$ valid XML files feature:
#
# - Unknown/typoed tags and attributes names
# - Missing affiliation
# - Nested affiliation
# - Affiliations `<aff>` with no `<contrib>` reference
# - ...
#
# Some of these issues are solved by the [scielo-clea v0.1](https://github.com/scieloorg/clea/releases/tag/v0.1.0) (henceforth named *Clea*), an article front matter metadata reader that gathers information from the XML traversal by means of fuzzy/approximate regexes. Its result for a single XML input is either a Python dictionary or a JSON HTTP response with a tabular structure. A CSV dataset was built from the XML dataset by joining and flattening every Clea result, effectively casting the XML dataset into a table-like dataset.
#
# The CSV dataset has a row for each `<aff>`-`<contrib>` matching pair (*inner join* approach), and the goal is to look for any information in the dataset that can be useful for a data sanitization process such as:
#
# - Filling the empty fields
# - Fixing typoed contents
# - Joining/grouping distinct values that have the same meaning

# %% [markdown]
# CSV file: https://drive.google.com/file/d/1XmBh6YlfPkB5WfYSolAMP1EA5e02jHQO/view?usp=sharing

# %% [markdown]
# ## Loading the CSV dataset

# %%
import pandas as pd

# %%
dataset_raw = pd.read_csv("inner_join_2018-06-04.csv", dtype=str, keep_default_na=False)
len(dataset_raw)
# Out:
# 94660

# %% [markdown]
# Some articles appeared more than once in the dataset, so let's remove the duplicates.

# %%
dataset = dataset_raw.drop_duplicates()
len(dataset)
# Out:
# 89451

# %% [markdown]
# That's the number of `<aff>`-`<contrib>` matching pairs.

# %% [markdown]
# ## General information

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89451 entries, 0 to 94659
# Data columns (total 39 columns):
# addr_city                        89451 non-null object
# addr_country                     89451 non-null object
# addr_country_code                89451 non-null object
# addr_postal_code                 89451 non-null object
# addr_state                       89451 non-null object
# aff_email                        89451 non-null object
# aff_id                           89451 non-null object
# aff_text                         89451 non-null object
# article_doi                      89451 non-null object
# article_publisher_id             89451 non-null object
# article_title                    89451 non-null object
# contrib_bio                      89451 non-null object
# contrib_degrees                  89451 non-null object
# contrib_email                    89451 non-null object
# contrib_given_names              89451 non-null object
# contrib_name                     89451 non-null object
# contrib_orcid                    89451 non-null object
# contrib_prefix                   89451 non-null object
# contrib_role                     89451 non-null object
# contrib_suffix                   89451 non-null object
# contrib_surname                  89451 non-null object
# contrib_type                     89451 non-null object
# institution_orgdiv1              89451 non-null object
# institution_orgdiv2              89451 non-null object
# institution_orgname              89451 non-null object
# institution_orgname_rewritten    89451 non-null object
# institution_original             89451 non-null object
# issn_epub                        89451 non-null object
# issn_ppub                        89451 non-null object
# journal_nlm_ta                   89451 non-null object
# journal_publisher_id             89451 non-null object
# journal_title                    89451 non-null object
# label                            89451 non-null object
# phone                            89451 non-null object
# publisher_name                   89451 non-null object
# xref_aff                         89451 non-null object
# xref_aff_text                    89451 non-null object
# xref_corresp                     89451 non-null object
# xref_corresp_text                89451 non-null object
# dtypes: object(39)
# memory usage: 27.3+ MB

# %%
dataset.describe().T
# Out:
#                                count unique  \
# addr_city                      89451   2729
# addr_country                   89451    267
# addr_country_code              89451    125
# addr_postal_code               89451    426
# addr_state                     89451    672
# aff_email                      89451  10068
# aff_id                         89451     60
# aff_text                       89451  49959
# article_doi                    89451  20551
# article_publisher_id           89451   5599
# article_title                  89451  18198
# contrib_bio                    89451     38
# contrib_degrees                89451     25
# contrib_email                  89451     38
# contrib_given_names            89451  53737
# contrib_name                   89451  69812
# contrib_orcid                  89451    633
# contrib_prefix                 89451      8
# contrib_role                   89451     51
# contrib_suffix                 89451     31
# contrib_surname                89451  25674
# contrib_type                   89451      7
# institution_orgdiv1            89451   9904
# institution_orgdiv2            89451   4822
# institution_orgname            89451   9652
# institution_orgname_rewritten  89451   2560
# institution_original           89451  45244
# issn_epub                      89451    307
# issn_ppub                      89451    279
# journal_nlm_ta                 89451     91
# journal_publisher_id           89451    317
# journal_title                  89451    325
# label                          89451    283
# phone                          89451      5
# publisher_name                 89451    356
# xref_aff                       89451    258
# xref_aff_text                  89451    481
# xref_corresp                   89451     65
# xref_corresp_text              89451     27
#
#                                                                              top  \
# addr_city
# addr_country                                                              Brazil
# addr_country_code                                                             BR
# addr_postal_code
# addr_state
# aff_email
# aff_id                                                                      aff1
# aff_text                       1 Hospital Israelita Albert Einstein Hospital ...
# article_doi                                            10.1590/1414-431X20122449
# article_publisher_id
# article_title
# contrib_bio
# contrib_degrees
# contrib_email
# contrib_given_names                                                     Fernando
# contrib_name                                              Malta Deborah Carvalho
# contrib_orcid
# contrib_prefix
# contrib_role
# contrib_suffix
# contrib_surname                                                            Silva
# contrib_type                                                              author
# institution_orgdiv1
# institution_orgdiv2
# institution_orgname                                    Universidade de São Paulo
# institution_orgname_rewritten
# institution_original
# issn_epub
# issn_ppub
# journal_nlm_ta
# journal_publisher_id
# journal_title                                            Brazilian Oral Research
# label                                                                          1
# phone
# publisher_name                               Universidade Federal de Santa Maria
# xref_aff                                                                    aff1
# xref_aff_text                                                                  1
# xref_corresp
# xref_corresp_text
#
#                                 freq
# addr_city                       9529
# addr_country                   48429
# addr_country_code              56596
# addr_postal_code               87918
# addr_state                     20906
# aff_email                      74478
# aff_id                         38355
# aff_text                         116
# article_doi                       56
# article_publisher_id           64392
# article_title                  12174
# contrib_bio                    89414
# contrib_degrees                89219
# contrib_email                  89414
# contrib_given_names              148
# contrib_name                      75
# contrib_orcid                  88760
# contrib_prefix                 89438
# contrib_role                   89236
# contrib_suffix                 87184
# contrib_surname                 2565
# contrib_type                   89403
# institution_orgdiv1            32933
# institution_orgdiv2            69045
# institution_orgname             5402
# institution_orgname_rewritten  29239
# institution_original            3955
# issn_epub                       4826
# issn_ppub                      13202
# journal_nlm_ta                 50658
# journal_publisher_id           14173
# journal_title                   2368
# label                          26260
# phone                          89444
# publisher_name                  2688
# xref_aff                       35244
# xref_aff_text                  24201
# xref_corresp                   80323
# xref_corresp_text              83564

# %% [markdown]
# There are many emptied fields that probably won't help at all. Some of them have few possible values, e.g.:

# %%
dataset["contrib_prefix"].unique().tolist()
# Out:
# ['', 'Filho', 'Junior', 'Pe.', 'Prof. Dr.', 'Dra.', 'Profa. Dra.', 'Dr.']

# %% [markdown]
# ## Contrib type

# %%
dataset.groupby("contrib_type").size()
# Out:
# contrib_type
#                      13
# author            89403
# author; author        2
# autor                 2
# editor               27
# organizer             2
# translator            2
# dtype: int64

# %% [markdown]
# - The `author; author` is due to a contrib with two affiliations;
# - The only single typo seem to be *autor* instead of *author*, that field was probably written in Portuguese;
# - By far, most contributors are authors;
# - The valid contrib types are at least `["author", "editor", "organizer", "translator"]`, but [the tag documentation](http://docs.scielo.org/projects/scielo-publishing-schema/pt_BR/1.8-branch/tagset/elemento-contrib.html) tells us there's at least `"compiler"` missing, though these other contrib types should include `<author-notes>` and `<fn>` giving us more information.
#
# There are a few missing/empty rows missing the contrib type. How do we find the empty contrib? The easiest approach would be to simply say these are *author*, since our "*prior*" leans towards it: $99.95\%$ of the input rows have this contrib type. That's to say that probably they're authors when we're biased towards this specific unbalanced dataset. And that's true as a probability: the best blind guess would be "author". But we can't reasonably say something about the contrib type unless we at least evaluate the row where it's in (i.e., information specific to the document), so we need to find another approach.

# %%
print("%.2f%%" % (89403 / 89451 * 100)) # "author" frequency (prior)
# Out:
# 99.95%

# %% [markdown]
# If we're lucky, the same contributor had contributed to another piece of work in the same dataset, so we can at least say he/she has a "type of contribution" elsewhere. That approach still might be wrong: the same person might perform different roles, and there might be homonyms; but it would be at least better than a blind guess.

# %%
ct_data = dataset[["contrib_given_names", "contrib_surname", "contrib_type"]]
ct_selector = ct_data["contrib_type"] == ""
ct_data_unfilled = ct_data[ct_selector]
ct_data_unfilled
# Out:
#          contrib_given_names contrib_surname contrib_type
# 49700        Emiko Yoshikawa            Egry
# 49701     Lucia Yasuko Izumi        Nichiata
# 86731                 Rafael        Pazinato
# 86732              Vanderlei          Klauck
# 86733                Andréia         Volpato
# 86734              Alexandre          Balzan
# 86735                  Julia         Rossett
# 86736      Chrystian Jassanã       Cazarotto
# 86737          Leandro Sâmia           Lopes
# 86738          Julcemar Dias         Kessler
# 86739          Diego Córdova           Cucco
# 86740  Aleksandro Schafer Da           Silva
# 86741      Alexandre Alberto           Tonin

# %% [markdown]
# These contributor names appear in some XML file missing the type of contribution. Let's get the "nearest" names (in a Levenshtein distance sense) in the remaining data. But, at first, we have to "pre-normalize" the names (remove accents and put in lowercase).

# %%
from functools import partial
import Levenshtein as lev
from unidecode import unidecode

# %%
ct_unknown = ct_data_unfilled.drop(
    columns=["contrib_type"],
).join(
    ct_data_unfilled.drop(columns=["contrib_type"])
                    .applymap(unidecode)
                    .applymap(str.lower),
    rsuffix="_n",
)
ct_unknown.sort_values(by=["contrib_given_names_n", "contrib_surname_n"])
# Out:
#          contrib_given_names contrib_surname  contrib_given_names_n  \
# 86740  Aleksandro Schafer Da           Silva  aleksandro schafer da
# 86734              Alexandre          Balzan              alexandre
# 86741      Alexandre Alberto           Tonin      alexandre alberto
# 86733                Andréia         Volpato                andreia
# 86736      Chrystian Jassanã       Cazarotto      chrystian jassana
# 86739          Diego Córdova           Cucco          diego cordova
# 49700        Emiko Yoshikawa            Egry        emiko yoshikawa
# 86738          Julcemar Dias         Kessler          julcemar dias
# 86735                  Julia         Rossett                  julia
# 86737          Leandro Sâmia           Lopes          leandro samia
# 49701     Lucia Yasuko Izumi        Nichiata     lucia yasuko izumi
# 86731                 Rafael        Pazinato                 rafael
# 86732              Vanderlei          Klauck              vanderlei
#
#       contrib_surname_n
# 86740             silva
# 86734            balzan
# 86741             tonin
# 86733           volpato
# 86736         cazarotto
# 86739             cucco
# 49700              egry
# 86738           kessler
# 86735           rossett
# 86737             lopes
# 49701          nichiata
# 86731          pazinato
# 86732            klauck

# %%
ct_data_filled = ct_data[~ct_selector]
ct_known = ct_data_filled.join(
    ct_data_filled.applymap(unidecode)
                  .applymap(str.lower),
    rsuffix="_n",
).drop(
    columns=["contrib_type_n"],
)
len(ct_known)
# Out:
# 89438

# %% [markdown]
# The ct_known is quite big. These names have some few repetitions:

# %%
pd.merge(ct_known, ct_unknown, how="right", on=["contrib_given_names_n", "contrib_surname_n"])
# Out:
#     contrib_given_names_x contrib_surname_x contrib_type  \
# 0         Emiko Yoshikawa              Egry       author
# 1         Emiko Yoshikawa              Egry       author
# 2         Emiko Yoshikawa              Egry       author
# 3         Emiko Yoshikawa              Egry       author
# 4         Emiko Yoshikawa              Egry       author
# 5         Emiko Yoshikawa              Egry       author
# 6         Emiko Yoshikawa              Egry       author
# 7         Emiko Yoshikawa              Egry       author
# 8         Emiko Yoshikawa              Egry       author
# 9         Emiko Yoshikawa              Egry       author
# 10                 Rafael          Pazinato       author
# 11              Vanderlei            Klauck       author
# 12                Andréia           Volpato       author
# 13              Alexandre            Balzan       author
# 14                  Julia           Rossett       author
# 15      Chrystian Jassanã         Cazarotto       author
# 16          Leandro Sâmia             Lopes       author
# 17          Julcemar Dias           Kessler       author
# 18          Diego Córdova             Cucco       author
# 19  Aleksandro Schafer Da             Silva       author
# 20      Alexandre Alberto             Tonin       author
# 21      Alexandre Alberto             Tonin       author
# 22                    NaN               NaN          NaN
#
#     contrib_given_names_n contrib_surname_n  contrib_given_names_y  \
# 0         emiko yoshikawa              egry        Emiko Yoshikawa
# 1         emiko yoshikawa              egry        Emiko Yoshikawa
# 2         emiko yoshikawa              egry        Emiko Yoshikawa
# 3         emiko yoshikawa              egry        Emiko Yoshikawa
# 4         emiko yoshikawa              egry        Emiko Yoshikawa
# 5         emiko yoshikawa              egry        Emiko Yoshikawa
# 6         emiko yoshikawa              egry        Emiko Yoshikawa
# 7         emiko yoshikawa              egry        Emiko Yoshikawa
# 8         emiko yoshikawa              egry        Emiko Yoshikawa
# 9         emiko yoshikawa              egry        Emiko Yoshikawa
# 10                 rafael          pazinato                 Rafael
# 11              vanderlei            klauck              Vanderlei
# 12                andreia           volpato                Andréia
# 13              alexandre            balzan              Alexandre
# 14                  julia           rossett                  Julia
# 15      chrystian jassana         cazarotto      Chrystian Jassanã
# 16          leandro samia             lopes          Leandro Sâmia
# 17          julcemar dias           kessler          Julcemar Dias
# 18          diego cordova             cucco          Diego Córdova
# 19  aleksandro schafer da             silva  Aleksandro Schafer Da
# 20      alexandre alberto             tonin      Alexandre Alberto
# 21      alexandre alberto             tonin      Alexandre Alberto
# 22     lucia yasuko izumi          nichiata     Lucia Yasuko Izumi
#
#    contrib_surname_y
# 0               Egry
# 1               Egry
# 2               Egry
# 3               Egry
# 4               Egry
# 5               Egry
# 6               Egry
# 7               Egry
# 8               Egry
# 9               Egry
# 10          Pazinato
# 11            Klauck
# 12           Volpato
# 13            Balzan
# 14           Rossett
# 15         Cazarotto
# 16             Lopes
# 17           Kessler
# 18             Cucco
# 19             Silva
# 20             Tonin
# 21             Tonin
# 22          Nichiata

# %% [markdown]
# Now we have a more specific information: most of these contributors had been author otherwhere, and nothing else. That's way better than just saying "most contributors overall are authors, so my guess is that this I-haven't-read-the-name-yet one should be author as well". This time, we're looking at the specifics, not a single class for every entry.
#
# The last entry (Lucia) doesn't match anyone. Are similar names meaningful?
# These are the non-repeated names without the exact matches:

# %%
ct_known_remain = ct_known[
    ~(ct_known["contrib_given_names_n"].isin(ct_unknown["contrib_given_names_n"]) &
      ct_known["contrib_surname_n"].isin(ct_unknown["contrib_surname_n"]))
].drop_duplicates()
len(ct_known_remain)
# Out:
# 69614

# %% [markdown]
# Let's find the 3 nearest non-equal names for each of those unknowns.
# This way of finding the nearest names might be slow, but it's enough for an experiment:

# %%
from functools import lru_cache

# %%
cached_lev_dist = lru_cache(None)(lev.distance)

# %%
def ct_series_apply(series):
    series["dist_given_names"] = cached_lev_dist(series["contrib_given_names_n_x"],
                                                 series["contrib_given_names_n_y"])
    series["dist_surname"] = cached_lev_dist(series["contrib_surname_n_x"],
                                             series["contrib_surname_n_y"])
    series["dist"] = series["dist_given_names"] / len(series["contrib_given_names_n_x"]) \
                   + series["dist_surname"] / len(series["contrib_surname_n_x"])
    return series

# %% [markdown]
# The distance measure is governed by these assumptions:
#
# - The given-name and the surname have the same weight;
# - The per-field Levenshtein distance should be normalized in order to compare inputs with different lengths;
# - The overall range is from 0 (equalness) to 2 (should modify every single character).

# %%
ct_nearest = pd.merge(ct_unknown.assign(_unused=1),
                      ct_known_remain.assign(_unused=1),
                      on="_unused") \
               .drop(columns=["_unused"]) \
               .apply(ct_series_apply, axis=1) \
               .groupby(["contrib_given_names_x", "contrib_surname_x"]) \
               .apply(lambda grp: grp.sort_values("dist")
                                     .loc[:, ["contrib_given_names_y",
                                               "contrib_surname_y",
                                               "contrib_type",
                                               "dist_given_names",
                                               "dist_surname",
                                               "dist"]]
                                     .iloc[:3])
ct_nearest
# Out:
#                                                  contrib_given_names_y  \
# contrib_given_names_x contrib_surname_x
# Aleksandro Schafer Da Silva             799338    Alessandro Salles da
#                                         798416        Alexsandro O. da
#                                         783035  Alexsandro Oliveira da
# Alexandre             Balzan            365704               Alexandre
#                                         353244               Alexandre
#                                         405684               Alexandre
# Alexandre Alberto     Tonin             842266          Rosane Baldiga
#                                         847430         Alexandre Penna
#                                         870064             Paulo César
# Andréia               Volpato           282623                  Andréa
#                                         305453                 Andreia
#                                         333925                 Andréia
# Chrystian Jassanã     Cazarotto         494277              Edson José
#                                         511743            Christian A.
#                                         523205                 Adriana
# Diego Córdova         Cucco             697148                   Cesar
#                                         737563                  Carine
#                                         754216           Débora Telles
# Emiko Yoshikawa       Egry              45047            Diogo Miranda
#                                         58747               João Elias
#                                         58925             Joilda Silva
# Julcemar Dias         Kessler           632943           Iruena Moraes
#                                         656888                  A de M
#                                         628384                 Adriana
# Julia                 Rossett           485631                   Júlia
#                                         421440                   Júlia
#                                         458384                   Julia
# Leandro Sâmia         Lopes             589961            Evandro Luiz
#                                         585212              André Luiz
#                                         613101             Andressa R.
# Lucia Yasuko Izumi    Nichiata          77716           Lucia Y. Izumi
#                                         132115             Lêni Márcia
#                                         87941           Renato Sussumu
# Rafael                Pazinato          194478                  Rafael
#                                         162010                  Rafael
#                                         200467                  Rafael
# Vanderlei             Klauck            211835               WANDERLEI
#                                         258871               Vanderlei
#                                         233114               VANDERLEI
#
#                                                contrib_surname_y contrib_type  \
# contrib_given_names_x contrib_surname_x
# Aleksandro Schafer Da Silva             799338             Silva       author
#                                         798416             Silva       author
#                                         783035             Silva       author
# Alexandre             Balzan            365704             Palma       author
#                                         353244            Uhlein       author
#                                         405684          Mazzanti       author
# Alexandre Alberto     Tonin             842266             Tonin       author
#                                         847430            Torini       author
#                                         870064             Tonin       author
# Andréia               Volpato           282623            Falcão       author
#                                         305453             Veiga       author
#                                         333925            Vielmo       author
# Chrystian Jassanã     Cazarotto         494277         Mazarotto       author
#                                         511743           Zanotti       author
#                                         523205         Cezaretto       author
# Diego Córdova         Cucco             697148             Zucco       author
#                                         737563             Cocco       author
#                                         754216             Cocco       author
# Emiko Yoshikawa       Egry              45047              Petry       author
#                                         58747               Nery       author
#                                         58925               Nery       author
# Julcemar Dias         Kessler           632943           Kessler       author
#                                         656888           Kessler       author
#                                         628384           Kessler       author
# Julia                 Rossett           485631           PESSINI       author
#                                         421440         Fochezato       author
#                                         458384          Noschang       author
# Leandro Sâmia         Lopes             589961             Lopes       author
#                                         585212             Lopes       author
#                                         613101             Lopes       author
# Lucia Yasuko Izumi    Nichiata          77716           Nichiata       author
#                                         132115          Anchieta       author
#                                         87941           NISHIOKA       author
# Rafael                Pazinato          194478           Fagnani       author
#                                         162010               PIO       author
#                                         200467           Matielo       author
# Vanderlei             Klauck            211835             LINKE       author
#                                         258871              Both       author
#                                         233114              BOTH       author
#
#                                                 dist_given_names  \
# contrib_given_names_x contrib_surname_x
# Aleksandro Schafer Da Silva             799338                 6
#                                         798416                 8
#                                         783035                 8
# Alexandre             Balzan            365704                 0
#                                         353244                 0
#                                         405684                 0
# Alexandre Alberto     Tonin             842266                12
#                                         847430                 6
#                                         870064                14
# Andréia               Volpato           282623                 1
#                                         305453                 0
#                                         333925                 0
# Chrystian Jassanã     Cazarotto         494277                12
#                                         511743                 7
#                                         523205                12
# Diego Córdova         Cucco             697148                11
#                                         737563                11
#                                         754216                11
# Emiko Yoshikawa       Egry              45047                 10
#                                         58747                 11
#                                         58925                 11
# Julcemar Dias         Kessler           632943                10
#                                         656888                10
#                                         628384                11
# Julia                 Rossett           485631                 0
#                                         421440                 0
#                                         458384                 0
# Leandro Sâmia         Lopes             589961                 6
#                                         585212                 7
#                                         613101                 7
# Lucia Yasuko Izumi    Nichiata          77716                  5
#                                         132115                13
#                                         87941                 13
# Rafael                Pazinato          194478                 0
#                                         162010                 0
#                                         200467                 0
# Vanderlei             Klauck            211835                 1
#                                         258871                 0
#                                         233114                 0
#
#                                                 dist_surname      dist
# contrib_given_names_x contrib_surname_x
# Aleksandro Schafer Da Silva             799338             0  0.285714
#                                         798416             0  0.380952
#                                         783035             0  0.380952
# Alexandre             Balzan            365704             3  0.500000
#                                         353244             4  0.666667
#                                         405684             4  0.666667
# Alexandre Alberto     Tonin             842266             0  0.705882
#                                         847430             2  0.752941
#                                         870064             0  0.823529
# Andréia               Volpato           282623             4  0.714286
#                                         305453             5  0.714286
#                                         333925             5  0.714286
# Chrystian Jassanã     Cazarotto         494277             1  0.816993
#                                         511743             4  0.856209
#                                         523205             2  0.928105
# Diego Córdova         Cucco             697148             1  1.046154
#                                         737563             1  1.046154
#                                         754216             1  1.046154
# Emiko Yoshikawa       Egry              45047              2  1.166667
#                                         58747              2  1.233333
#                                         58925              2  1.233333
# Julcemar Dias         Kessler           632943             0  0.769231
#                                         656888             0  0.769231
#                                         628384             0  0.846154
# Julia                 Rossett           485631             5  0.714286
#                                         421440             6  0.857143
#                                         458384             6  0.857143
# Leandro Sâmia         Lopes             589961             0  0.461538
#                                         585212             0  0.538462
#                                         613101             0  0.538462
# Lucia Yasuko Izumi    Nichiata          77716              0  0.277778
#                                         132115             3  1.097222
#                                         87941              3  1.097222
# Rafael                Pazinato          194478             5  0.625000
#                                         162010             5  0.625000
#                                         200467             5  0.625000
# Vanderlei             Klauck            211835             5  0.944444
#                                         258871             6  1.000000
#                                         233114             6  1.000000

# %% [markdown]
# Most of these names regard to distinct people, and there's no typographical error entry. It's pretty hard to find a meaningful relationship using this Levenshtein distance approach, besides typos. On the other hand, we've found a name that seems to match Lucia Yasuko Izumi Nichiata, with Yasuko shortened to "Y.". If she's really an author otherwhere in the dataset, then everyone missing information seem to be an author. Actually, every contributor that appeared in the exaples above is an author.
#
# We can *feel* that `Lucia Y. Izumi` and `Lucia Yasuko Izumi` are similar and probably the same person, but it doesn't seem obvious how to automate that.

# %% [markdown]
# Another distance approach would be to use the full names names segregated by words, with different weights for stuff like:
#
# - number of chars
# - leading/trailing char
# - set of chars difference
# - amount of chars difference
# - ...
